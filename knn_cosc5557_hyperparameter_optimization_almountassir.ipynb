# %% [markdown]
# # Hyperparameter Optimization
#
# For this exercise, we will have a look at Hyperparameter Optimization --
# instead of just choosing the best type of machine learning model, we also want
# to choose the best hyperparameter setting for a task. The end result (i.e. the
# predictive performance) is again not important; how you get there is.
#
# Your deliverable will be a report, written in a style that it
# would be suitable for inclusion in an academic paper as the "Experimental
# Setup" section or similar. If unsure, check an academic paper of your choice,
# for example [this one](https://www.eecs.uwyo.edu/~larsko/papers/pulatov_opening_2022-1.pdf). The
# level of detail should be higher than in a typical academic paper though. Your
# report should be at most five pages, including references and figures but
# excluding appendices. It should have the following structure:
# - Introduction: What problem are you solving, how are you going to solve it.
# - Dataset Description: Describe the data you're using, e.g. how many features and observations, what are you predicting, any missing values, etc.
# - Experimental Setup: What specifically are you doing to solve the problem, i.e.\ what programming languages and libraries, how are you processing the data, what machine learning algorithms are you considering and what hyperparameters and value ranges, what measures you are using to evaluate them, what hyperparameter optimization method you chose, etc.
# - Results: Description of what you observed, including plots. Compare
#   performance before and after tuning, and show the best configuration.
# - Code: Add the code you've used as a separate file.
#
# Your report must contain enough detail to reproduce what you did without the
# code. If in doubt, include more detail.
#
# There is no required format for the report. You could, for example, use an
# iPython notebook.
#
# ## Data and Setup
#
# We will have a look at the [Wine Quality
# dataset](https://archive-beta.ics.uci.edu/dataset/186/wine+quality). Choose the
# one that corresponds to your preference in wine. You may also use a dataset of
# your choice, for example one that's relevant to your research.
#
# Choose a small number of different machine learning algorithms and
# hyperparameters, along with value ranges, for each. You can use implementations
# of AutoML systems (e.g. auto-sklearn), scientific papers, or the documentation
# of the library you are using to determine the hyperparameters to tune and the
# value ranges. Note that there is not only a single way to do this, but define a
# reasonable space (e.g. don't include whether to turn on debug output, or random
# forests with 1,000,000 trees, or tune the loss function). Your hyperparameter
# search space should be so large that you cannot simply run a grid search.
#
# Determine the best machine learning algorithm and hyperparameter setting for
# your dataset. Make sure to optimize both the type of machine learning algorithm
# and the hyperparameters at the same time (do not first choose the best ML
# algorithm and then optimize its hyperparameters). Choose a suitable
# hyperparameter optimizer; you could also use several and e.g. compare the
# results achieved by random search and Bayesian optimization. Make sure that the
# way you evaluate model performance avoids bias and overfitting. You could use
# statistical tests to make this determination.
#
# ## Submission
#
# Add your report and code to this repository. Bonus points if you can set up a
# Github action to automatically run the code and generate the report!

# %% [markdown]
# ## Useful Resources :
# - "*Basics of HPO - Example and Practical Hints*" -From the AutoML Course Videos
# - https://www.youtube.com/watch?v=Gol_qOgRqfA
# - https://www.youtube.com/watch?v=0wUF_Ov8b0A&t=1058s

# %% [markdown]
# ## Importing the Dataset as a Pandas Dataframe

# %%
import pandas as pd
import numpy as np

# %%
red_wine_df = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X = red_wine_df.iloc[:, :-1]
y = red_wine_df['quality']

X.shape, y.shape
# Out:
# ((1599, 11), (1599,))

# %% [markdown]
# ## Importing our Model (KNN Classifier)

# %% [markdown]
# ### K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier()

# %%
knn_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %% [markdown]
# ## Needed Data Pre-processing for KNN

# %%
# RESOURCE : https://arize.com/blog-course/knn-algorithm-k-nearest-neighbor/#:~:text=Preprocessing%20Data&text=Scaling%20the%20data%20is%20an,can%20result%20in%20incorrect%20classifications.
# Preprocess the data for the KNN model:

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Hyperparameter Optimization
#
# Methods Used :
# - Bayesian Optimization
# - Random Search

# %% [markdown]
# ### Bayesian Optimization

# %%
# Comment out this line to install the necessary library for Bayesian Optimization:
# !pip install baytune
# Out:
# Requirement already satisfied: baytune in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: copulas>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from baytune) (0.10.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.2.2)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.11.4)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.5.3)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from baytune) (4.66.2)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from copulas>=0.3.2->baytune) (5.15.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (3.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1->baytune) (1.16.0)

# %%
models = {
    'KNN': KNeighborsClassifier,
}

# %%
from sklearn.model_selection import cross_val_score

def scoring_function(model_name, hyperparameter_values):
    model_class = models[model_name]
    model_instance = model_class(**hyperparameter_values)
    scores = cross_val_score(
        cv=10,
        estimator=model_instance,
        X=X_scaled,
        y=y,
        scoring='accuracy',
    )

    return scores.mean()

# %%
from baytune.tuning import Tunable
from baytune.tuning import hyperparams as hp

tunables = {
    'KNN': Tunable({
        'n_neighbors': hp.IntHyperParam(min=1, max=1000, default=5),
        'weights' : hp.CategoricalHyperParam(choices=['uniform', 'distance'], default='uniform'),
        'algorithm' : hp.CategoricalHyperParam(choices=['auto', 'ball_tree', 'kd_tree', 'brute'], default='auto'),
        'leaf_size' : hp.IntHyperParam(min=1, max=100000, default=30),
        'p' : hp.IntHyperParam(min=1, max=100000, default=2)
    }),
}

# %%
from baytune import BTBSession

session = BTBSession(
    tunables=tunables,
    scorer=scoring_function,
    verbose=True,
)

# %%
best_result = session.run(50)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
best_result
# Out:
# {'id': '804ea6e0183e7138ddb10c8165e4eabc',
#  'name': 'KNN',
#  'config': {'n_neighbors': 241,
#   'weights': 'distance',
#   'algorithm': 'kd_tree',
#   'leaf_size': 39403,
#   'p': 836},
#  'score': 0.5584669811320755}

# %% [markdown]
# ### Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### K-Nearest Neighbors

# %%
# Define the hyperparameters:

k_neighbors = range(1, 1000)
weights = ['uniform', 'distance']
algorithms = ['auto', 'ball_tree', 'kd_tree', 'brute']
leaf_sizes = range(1, 100000)
p_values = range(1, 100000)

# %%
# Construct the hyperparameter distribution:

hyperparameter_distribution = {
    "n_neighbors" : k_neighbors,
    "weights" : weights,
    "algorithm" : algorithms,
    "leaf_size" : leaf_sizes,
    "p" : p_values
}

# %%
# Construct the "Random Search" object:

K_FOLDS = 10
ITERATIONS = 200
random_search = RandomizedSearchCV(knn_model, hyperparameter_distribution, cv=K_FOLDS, scoring='accuracy', n_iter=ITERATIONS, verbose=4)

# %%
# Run the "Random Search" on the dataset and on the hyperparameter distribution:

random_search.fit(X_scaled, y)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [CV 1/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.044 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.3s
# [CV 3/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.2s
# [CV 4/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.2s
# [CV 9/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.425 total time=   0.2s
# [CV 10/10] END algorithm=auto, leaf_size=70081, n_neighbors=233, p=65145, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.037 total time=   0.2s
# [CV 2/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.2s
# [CV 3/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.3s
# [CV 4/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.5s
# [CV 5/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.5s
# [CV 6/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.4s
# [CV 7/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.3s
# [CV 8/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.5s
# [CV 9/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.425 total time=   0.2s
# [CV 10/10] END algorithm=ball_tree, leaf_size=48205, n_neighbors=583, p=93676, weights=uniform;, score=0.428 total time=   0.2s
# [CV 1/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.037 total time=   0.3s
# [CV 2/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.3s
# [CV 3/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.3s
# [CV 4/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.2s
# [CV 5/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.2s
# [CV 6/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.3s
# [CV 7/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.2s
# [CV 8/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.2s
# [CV 9/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.425 total time=   0.3s
# [CV 10/10] END algorithm=ball_tree, leaf_size=24067, n_neighbors=442, p=12714, weights=uniform;, score=0.428 total time=   0.3s
# [CV 1/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.056 total time=   0.2s
# [CV 2/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.431 total time=   0.2s
# [CV 3/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.419 total time=   0.2s
# [CV 4/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.431 total time=   0.2s
# [CV 5/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.419 total time=   0.2s
# [CV 6/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.431 total time=   0.2s
# [CV 7/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.425 total time=   0.2s
# [CV 8/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.425 total time=   0.2s
# [CV 9/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.425 total time=   0.2s
# [CV 10/10] END algorithm=auto, leaf_size=59034, n_neighbors=130, p=53559, weights=uniform;, score=0.428 total time=   0.2s
# [CV 1/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.037 total time=   0.3s
# [CV 2/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.3s
# [CV 3/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.2s
# [CV 4/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.4s
# [CV 5/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.5s
# [CV 6/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.2s
# [CV 7/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.4s
# [CV 8/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.3s
# [CV 9/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.425 total time=   0.3s
# [CV 10/10] END algorithm=ball_tree, leaf_size=86107, n_neighbors=737, p=65985, weights=uniform;, score=0.428 total time=   0.3s
# [CV 1/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.037 total time=   0.2s
# [CV 2/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.3s
# [CV 3/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.2s
# [CV 4/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.2s
# [CV 5/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.3s
# [CV 6/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.2s
# [CV 7/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.3s
# [CV 8/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.2s
# [CV 9/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.425 total time=   0.3s
# [CV 10/10] END algorithm=brute, leaf_size=15666, n_neighbors=350, p=67622, weights=uniform;, score=0.428 total time=   0.4s
# [CV 1/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.419 total time=   0.5s
# [CV 2/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.450 total time=   0.5s
# [CV 3/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.450 total time=   0.2s
# [CV 4/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.388 total time=   0.2s
# [CV 5/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.394 total time=   0.2s
# [CV 6/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.606 total time=   0.2s
# [CV 7/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.594 total time=   0.2s
# [CV 8/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.500 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=59771, n_neighbors=576, p=66673, weights=distance;, score=0.509 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.419 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.450 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.450 total time=   0.1s
# [CV 4/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.388 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.394 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.606 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.594 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.500 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=90925, n_neighbors=361, p=64027, weights=distance;, score=0.509 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.056 total time=   0.1s
# [CV 2/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.419 total time=   0.1s
# [CV 4/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.431 total time=   0.1s
# [CV 7/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=91022, n_neighbors=144, p=69295, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=20507, n_neighbors=756, p=13569, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.419 total time=   0.2s
# [CV 2/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.450 total time=   0.1s
# [CV 3/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.450 total time=   0.1s
# [CV 4/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.388 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.394 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.606 total time=   0.1s
# [CV 7/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.594 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.500 total time=   0.2s
# [CV 9/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=66216, n_neighbors=835, p=78421, weights=distance;, score=0.509 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.050 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=28188, n_neighbors=206, p=22560, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=17221, n_neighbors=347, p=15892, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=33613, n_neighbors=272, p=24265, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.412 total time=   0.1s
# [CV 2/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.481 total time=   0.1s
# [CV 3/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.463 total time=   0.1s
# [CV 4/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.412 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.600 total time=   0.1s
# [CV 7/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.556 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.500 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.531 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=33597, n_neighbors=120, p=10468, weights=distance;, score=0.522 total time=   0.1s
# [CV 1/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.2s
# [CV 5/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.2s
# [CV 6/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.2s
# [CV 7/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.3s
# [CV 8/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.2s
# [CV 9/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.425 total time=   0.2s
# [CV 10/10] END algorithm=brute, leaf_size=52035, n_neighbors=471, p=53089, weights=uniform;, score=0.428 total time=   0.3s
# [CV 1/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.412 total time=   0.2s
# [CV 2/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.450 total time=   0.2s
# [CV 3/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.450 total time=   0.2s
# [CV 4/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.388 total time=   0.2s
# [CV 5/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.394 total time=   0.2s
# [CV 6/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.606 total time=   0.2s
# [CV 7/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.594 total time=   0.2s
# [CV 8/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.494 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=2545, n_neighbors=783, p=87915, weights=distance;, score=0.509 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.412 total time=   0.1s
# [CV 2/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.450 total time=   0.1s
# [CV 3/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.444 total time=   0.1s
# [CV 4/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.394 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.381 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.606 total time=   0.1s
# [CV 7/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.600 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.500 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=96553, n_neighbors=678, p=33187, weights=distance;, score=0.503 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.331 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.456 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.456 total time=   0.1s
# [CV 4/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.438 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.487 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.544 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.581 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.575 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.475 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=32105, n_neighbors=25, p=50894, weights=uniform;, score=0.459 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.2s
# [CV 7/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=17514, n_neighbors=724, p=6057, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.138 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.431 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.412 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.438 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.419 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.438 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.406 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.469 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=74434, n_neighbors=102, p=80401, weights=uniform;, score=0.440 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.356 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.450 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.456 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.444 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.444 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.550 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.544 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.550 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.500 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=26932, n_neighbors=36, p=6166, weights=uniform;, score=0.472 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=80808, n_neighbors=636, p=86123, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.481 total time=   0.1s
# [CV 2/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.588 total time=   0.1s
# [CV 3/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.544 total time=   0.1s
# [CV 4/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.537 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.487 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.631 total time=   0.1s
# [CV 7/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.575 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.506 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.569 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=93650, n_neighbors=854, p=101, weights=distance;, score=0.516 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.412 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.450 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.450 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.388 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.394 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.606 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.594 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.494 total time=   0.2s
# [CV 9/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.556 total time=   0.2s
# [CV 10/10] END algorithm=ball_tree, leaf_size=39078, n_neighbors=424, p=95194, weights=distance;, score=0.509 total time=   0.2s
# [CV 1/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.431 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.469 total time=   0.2s
# [CV 3/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.487 total time=   0.2s
# [CV 4/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.400 total time=   0.2s
# [CV 5/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.425 total time=   0.2s
# [CV 6/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.594 total time=   0.2s
# [CV 7/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.569 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.525 total time=   0.2s
# [CV 9/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.525 total time=   0.2s
# [CV 10/10] END algorithm=ball_tree, leaf_size=72418, n_neighbors=138, p=14070, weights=distance;, score=0.478 total time=   0.2s
# [CV 1/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.056 total time=   0.2s
# [CV 2/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.2s
# [CV 3/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.2s
# [CV 4/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=55251, n_neighbors=234, p=9490, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.419 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.450 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.450 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.388 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.394 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.606 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.594 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.500 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=80827, n_neighbors=352, p=68423, weights=distance;, score=0.509 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.431 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.500 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.506 total time=   0.1s
# [CV 4/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.438 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.481 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.613 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.606 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.588 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.550 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=98937, n_neighbors=842, p=69682, weights=distance;, score=0.553 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.050 total time=   0.1s
# [CV 2/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=kd_tree, leaf_size=13617, n_neighbors=202, p=47366, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.438 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.519 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.500 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.456 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.512 total time=   0.1s
# [CV 6/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.613 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.544 total time=   0.1s
# [CV 8/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.613 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.512 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=8521, n_neighbors=89, p=19699, weights=distance;, score=0.503 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.044 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=12885, n_neighbors=234, p=98013, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.037 total time=   0.2s
# [CV 2/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 3/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 4/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 5/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 6/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 7/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 8/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 9/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.425 total time=   0.2s
# [CV 10/10] END algorithm=kd_tree, leaf_size=14379, n_neighbors=928, p=36492, weights=uniform;, score=0.428 total time=   0.2s
# [CV 1/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.425 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.500 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.506 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.438 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.481 total time=   0.1s
# [CV 6/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.613 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.606 total time=   0.1s
# [CV 8/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.581 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.550 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=47352, n_neighbors=181, p=96549, weights=distance;, score=0.553 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=23028, n_neighbors=529, p=47452, weights=uniform;, score=0.428 total time=   0.2s
# [CV 1/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.087 total time=   0.2s
# [CV 2/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.425 total time=   0.2s
# [CV 3/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.425 total time=   0.2s
# [CV 4/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.425 total time=   0.2s
# [CV 5/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.425 total time=   0.2s
# [CV 6/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.425 total time=   0.2s
# [CV 7/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.425 total time=   0.2s
# [CV 8/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.425 total time=   0.2s
# [CV 9/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.419 total time=   0.2s
# [CV 10/10] END algorithm=ball_tree, leaf_size=57028, n_neighbors=411, p=2176, weights=uniform;, score=0.428 total time=   0.2s
# [CV 1/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.412 total time=   0.2s
# [CV 2/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.450 total time=   0.2s
# [CV 3/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.450 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.388 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.394 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.606 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.594 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.494 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=80235, n_neighbors=634, p=91860, weights=distance;, score=0.509 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.412 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.450 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.444 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.388 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.381 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.606 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.600 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.500 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=77315, n_neighbors=588, p=38126, weights=distance;, score=0.503 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=63475, n_neighbors=113, p=68804, weights=uniform;, score=0.087 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=63475, n_neighbors=113, p=68804, weights=uniform;, score=0.431 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=63475, n_neighbors=113, p=68804, weights=uniform;, score=0.419 total time=   0.1s
# ...
# [CV 7/10] END algorithm=kd_tree, leaf_size=17951, n_neighbors=810, p=83709, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=kd_tree, leaf_size=17951, n_neighbors=810, p=83709, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=kd_tree, leaf_size=17951, n_neighbors=810, p=83709, weights=uniform;, score=0.425 total time=   0.2s
# [CV 10/10] END algorithm=kd_tree, leaf_size=17951, n_neighbors=810, p=83709, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.425 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.500 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.500 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.438 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.469 total time=   0.1s
# [CV 6/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.613 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.613 total time=   0.1s
# [CV 8/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.588 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.550 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=64952, n_neighbors=357, p=48100, weights=distance;, score=0.547 total time=   0.1s
# [CV 1/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.2s
# [CV 6/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.2s
# [CV 8/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=363, n_neighbors=834, p=61000, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=99307, n_neighbors=250, p=44952, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.431 total time=   0.2s
# [CV 2/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.500 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.506 total time=   0.2s
# [CV 4/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.438 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.481 total time=   0.1s
# [CV 6/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.613 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.606 total time=   0.1s
# [CV 8/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.588 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.550 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=88246, n_neighbors=913, p=65622, weights=distance;, score=0.553 total time=   0.2s
# [CV 1/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.419 total time=   0.2s
# [CV 2/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.450 total time=   0.2s
# [CV 3/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.450 total time=   0.2s
# [CV 4/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.388 total time=   0.2s
# [CV 5/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.394 total time=   0.2s
# [CV 6/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.606 total time=   0.2s
# [CV 7/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.594 total time=   0.2s
# [CV 8/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.500 total time=   0.2s
# [CV 9/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.556 total time=   0.2s
# [CV 10/10] END algorithm=kd_tree, leaf_size=66113, n_neighbors=949, p=73450, weights=distance;, score=0.509 total time=   0.2s
# [CV 1/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.062 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.419 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.419 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.431 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=39829, n_neighbors=141, p=28300, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=ball_tree, leaf_size=49083, n_neighbors=356, p=46476, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.037 total time=   0.2s
# [CV 2/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 3/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 4/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 5/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 6/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 7/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 8/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 9/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.425 total time=   0.3s
# [CV 10/10] END algorithm=kd_tree, leaf_size=37424, n_neighbors=937, p=73270, weights=uniform;, score=0.428 total time=   0.3s
# [CV 1/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.056 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=87749, n_neighbors=189, p=19411, weights=uniform;, score=0.428 total time=   0.1s
# [CV 1/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.419 total time=   0.2s
# [CV 2/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.450 total time=   0.2s
# [CV 3/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.450 total time=   0.2s
# [CV 4/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.388 total time=   0.1s
# [CV 5/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.394 total time=   0.2s
# [CV 6/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.606 total time=   0.2s
# [CV 7/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.594 total time=   0.2s
# [CV 8/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.500 total time=   0.2s
# [CV 9/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.556 total time=   0.2s
# [CV 10/10] END algorithm=kd_tree, leaf_size=24514, n_neighbors=872, p=62793, weights=distance;, score=0.509 total time=   0.2s
# [CV 1/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.469 total time=   0.1s
# [CV 2/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.594 total time=   0.1s
# [CV 3/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.562 total time=   0.1s
# [CV 4/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.500 total time=   0.1s
# [CV 5/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.494 total time=   0.1s
# [CV 6/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.600 total time=   0.1s
# [CV 7/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.581 total time=   0.1s
# [CV 8/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.512 total time=   0.1s
# [CV 9/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.556 total time=   0.1s
# [CV 10/10] END algorithm=brute, leaf_size=8388, n_neighbors=575, p=114, weights=uniform;, score=0.535 total time=   0.1s
# [CV 1/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.037 total time=   0.1s
# [CV 2/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 3/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.2s
# [CV 4/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 5/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 6/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 7/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 8/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 9/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.425 total time=   0.1s
# [CV 10/10] END algorithm=auto, leaf_size=4434, n_neighbors=888, p=60265, weights=uniform;, score=0.428 total time=   0.2s
# RandomizedSearchCV(cv=10, estimator=KNeighborsClassifier(), n_iter=200,
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'leaf_size': range(1, 100000),
#                                         'n_neighbors': range(1, 1000),
#                                         'p': range(1, 100000),
#                                         'weights': ['uniform', 'distance']},
#                    scoring='accuracy', verbose=4)

# %%
# Check the results:

pd.DataFrame(random_search.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#      mean_test_score  std_test_score  \
# 0           0.387142        0.114467
# 1           0.386517        0.116342
# 2           0.386517        0.116342
# 3           0.389017        0.111010
# 4           0.386517        0.116342
# ..               ...             ...
# 195         0.386517        0.116342
# 196         0.388392        0.110717
# 197         0.486568        0.075547
# 198         0.540334        0.043082
# 199         0.386517        0.116342
#
#                                                 params
# 0    {'weights': 'uniform', 'p': 65145, 'n_neighbor...
# 1    {'weights': 'uniform', 'p': 93676, 'n_neighbor...
# 2    {'weights': 'uniform', 'p': 12714, 'n_neighbor...
# 3    {'weights': 'uniform', 'p': 53559, 'n_neighbor...
# 4    {'weights': 'uniform', 'p': 65985, 'n_neighbor...
# ..                                                 ...
# 195  {'weights': 'uniform', 'p': 73270, 'n_neighbor...
# 196  {'weights': 'uniform', 'p': 19411, 'n_neighbor...
# 197  {'weights': 'distance', 'p': 62793, 'n_neighbo...
# 198  {'weights': 'uniform', 'p': 114, 'n_neighbors'...
# 199  {'weights': 'uniform', 'p': 60265, 'n_neighbor...
#
# [200 rows x 3 columns]

# %%
print(random_search.best_score_)
print(random_search.best_params_)
# Out:
# 0.5459551886792453
# {'weights': 'uniform', 'p': 168, 'n_neighbors': 403, 'leaf_size': 18717, 'algorithm': 'ball_tree'}
