# %% [markdown]
# # Hyperparameter Optimization
#
# For this exercise, we will have a look at Hyperparameter Optimization --
# instead of just choosing the best type of machine learning model, we also want
# to choose the best hyperparameter setting for a task. The end result (i.e. the
# predictive performance) is again not important; how you get there is.
#
# Your deliverable will be a report, written in a style that it
# would be suitable for inclusion in an academic paper as the "Experimental
# Setup" section or similar. If unsure, check an academic paper of your choice,
# for example [this one](https://www.eecs.uwyo.edu/~larsko/papers/pulatov_opening_2022-1.pdf). The
# level of detail should be higher than in a typical academic paper though. Your
# report should be at most five pages, including references and figures but
# excluding appendices. It should have the following structure:
# - Introduction: What problem are you solving, how are you going to solve it.
# - Dataset Description: Describe the data you're using, e.g. how many features and observations, what are you predicting, any missing values, etc.
# - Experimental Setup: What specifically are you doing to solve the problem, i.e.\ what programming languages and libraries, how are you processing the data, what machine learning algorithms are you considering and what hyperparameters and value ranges, what measures you are using to evaluate them, what hyperparameter optimization method you chose, etc.
# - Results: Description of what you observed, including plots. Compare
#   performance before and after tuning, and show the best configuration.
# - Code: Add the code you've used as a separate file.
#
# Your report must contain enough detail to reproduce what you did without the
# code. If in doubt, include more detail.
#
# There is no required format for the report. You could, for example, use an
# iPython notebook.
#
# ## Data and Setup
#
# We will have a look at the [Wine Quality
# dataset](https://archive-beta.ics.uci.edu/dataset/186/wine+quality). Choose the
# one that corresponds to your preference in wine. You may also use a dataset of
# your choice, for example one that's relevant to your research.
#
# Choose a small number of different machine learning algorithms and
# hyperparameters, along with value ranges, for each. You can use implementations
# of AutoML systems (e.g. auto-sklearn), scientific papers, or the documentation
# of the library you are using to determine the hyperparameters to tune and the
# value ranges. Note that there is not only a single way to do this, but define a
# reasonable space (e.g. don't include whether to turn on debug output, or random
# forests with 1,000,000 trees, or tune the loss function). Your hyperparameter
# search space should be so large that you cannot simply run a grid search.
#
# Determine the best machine learning algorithm and hyperparameter setting for
# your dataset. Make sure to optimize both the type of machine learning algorithm
# and the hyperparameters at the same time (do not first choose the best ML
# algorithm and then optimize its hyperparameters). Choose a suitable
# hyperparameter optimizer; you could also use several and e.g. compare the
# results achieved by random search and Bayesian optimization. Make sure that the
# way you evaluate model performance avoids bias and overfitting. You could use
# statistical tests to make this determination.
#
# ## Submission
#
# Add your report and code to this repository. Bonus points if you can set up a
# Github action to automatically run the code and generate the report!

# %% [markdown]
# ## Useful Resources :
# - "*Basics of HPO - Example and Practical Hints*" -From the AutoML Course Videos
# - https://www.youtube.com/watch?v=Gol_qOgRqfA
# - https://www.youtube.com/watch?v=0wUF_Ov8b0A&t=1058s
# - https://www.geeksforgeeks.org/stratified-k-fold-cross-validation/
# - https://www.youtube.com/watch?v=-d338rc076s

# %% [markdown]
# ## Importing the Dataset as a Pandas Dataframe

# %%
import pandas as pd
import numpy as np

# %%
red_wine_df = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X = red_wine_df.iloc[:, :-1]
y = red_wine_df['quality']

X.shape, y.shape
# Out:
# ((1599, 11), (1599,))

# %% [markdown]
# ## Importing our Model (KNN Classifier)

# %% [markdown]
# ### K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier()

# %%
knn_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %% [markdown]
# ## Needed Data Pre-processing for KNN

# %%
# RESOURCE : https://arize.com/blog-course/knn-algorithm-k-nearest-neighbor/#:~:text=Preprocessing%20Data&text=Scaling%20the%20data%20is%20an,can%20result%20in%20incorrect%20classifications.
# Preprocess the data for the KNN model:

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Hyperparameter Optimization
#
# Methods Used :
# - Bayesian Optimization
# - Random Search

# %% [markdown]
# ### Bayesian Optimization

# %%
# Comment out this line to install the necessary library for Bayesian Optimization:
# !pip install baytune
# Out:
# Collecting baytune
#   Downloading baytune-0.5.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 kB 1.1 MB/s eta 0:00:00
# Collecting copulas>=0.3.2 (from baytune)
#   Downloading copulas-0.10.1-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.2.2)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.11.4)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.5.3)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from baytune) (4.66.2)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from copulas>=0.3.2->baytune) (5.15.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (3.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1->baytune) (1.16.0)
# Installing collected packages: copulas, baytune
# Successfully installed baytune-0.5.0 copulas-0.10.1

# %%
models = {
    'KNN': KNeighborsClassifier,
}

# %%
from baytune.tuning import Tunable
from baytune.tuning import hyperparams as hp

tunables = {
    'KNN': Tunable({
        'n_neighbors': hp.IntHyperParam(min=1, max=1000, default=5),
        'weights' : hp.CategoricalHyperParam(choices=['uniform', 'distance'], default='uniform'),
        'algorithm' : hp.CategoricalHyperParam(choices=['auto', 'ball_tree', 'kd_tree', 'brute'], default='auto'),
        'leaf_size' : hp.IntHyperParam(min=1, max=100000, default=30),
        'p' : hp.IntHyperParam(min=1, max=100000, default=2)
    }),
}

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from baytune import BTBSession

inner_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=90)
outer_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=90)
best_configurations = []
best_scores = []

for train_index, test_index in outer_fold.split(X_scaled, y):
    X_train, X_test = X_scaled[train_index], X_scaled[test_index]
    y_train, y_test = y[train_index], y[test_index]

    def scoring_function(model_name, hyperparameter_values):
        model_class = models[model_name]
        model_instance = model_class(**hyperparameter_values)
        scores = cross_val_score(
            cv=inner_fold,
            estimator=model_instance,
            X=X_train,
            y=y_train,
            scoring='accuracy',
        )

        return scores.mean()

    session = BTBSession(
        tunables=tunables,
        scorer=scoring_function,
        verbose=True,
    )

    best_result = session.run(30)

    best_model_name = best_result['name']
    hyperparameters = best_result['config']
    best_model_class = models[best_model_name]
    model_instance = best_model_class(**hyperparameters)

    model_instance.fit(X_train, y_train)

    score = model_instance.score(X_test, y_test)

    best_scores.append(score)
    best_configurations.append({
        "hyper-parameters" : hyperparameters,
        "performance_estimate" : score
    })
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
for configuration in best_configurations:
  print(configuration)
  print("****************************************************")
  print("****************************************************")
# Out:
# {'hyper-parameters': {'n_neighbors': 59, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 12599, 'p': 569}, 'performance_estimate': 0.60625}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 720, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 48994, 'p': 7429}, 'performance_estimate': 0.65625}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 845, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 3116, 'p': 42746}, 'performance_estimate': 0.55625}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 850, 'weights': 'distance', 'algorithm': 'brute', 'leaf_size': 61168, 'p': 88186}, 'performance_estimate': 0.575}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 5, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 30, 'p': 2}, 'performance_estimate': 0.58125}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 172, 'weights': 'distance', 'algorithm': 'brute', 'leaf_size': 99776, 'p': 52691}, 'performance_estimate': 0.5625}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 790, 'weights': 'distance', 'algorithm': 'brute', 'leaf_size': 81669, 'p': 26049}, 'performance_estimate': 0.56875}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 5, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 30, 'p': 2}, 'performance_estimate': 0.575}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 5, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 30, 'p': 2}, 'performance_estimate': 0.525}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_neighbors': 786, 'weights': 'distance', 'algorithm': 'brute', 'leaf_size': 82454, 'p': 11865}, 'performance_estimate': 0.5974842767295597}
# ****************************************************
# ****************************************************

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize =(10, 7))

plt.boxplot(best_scores)

plt.title("Model Performance Estimates")

plt.ylabel("Accuracy")

plt.show()

# %%
np.array(best_scores).mean()
# Out:
# 0.580373427672956

# %% [markdown]
# ### Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### K-Nearest Neighbors

# %%
k_neighbors = range(1, 500)
weights = ['uniform', 'distance']
algorithms = ['auto', 'ball_tree', 'kd_tree', 'brute']
leaf_sizes = range(1, 100000)
p_values = range(1, 100000)

# %%
hyperparameter_distribution = {
    "n_neighbors" : k_neighbors,
    "weights" : weights,
    "algorithm" : algorithms,
    "leaf_size" : leaf_sizes,
    "p" : p_values
}

# %%
from sklearn.model_selection import StratifiedKFold

inner_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=90)
outer_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=90)

ITERATIONS = 50
random_search = RandomizedSearchCV(
    knn_model,
    hyperparameter_distribution,
    cv=inner_fold,
    scoring='accuracy',
    n_iter=ITERATIONS,
    verbose=4
)

best_configurations = []
best_scores = []

for train_index, test_index in outer_fold.split(X_scaled, y):
    X_train, X_test = X_scaled[train_index], X_scaled[test_index]
    y_train, y_test = y[train_index], y[test_index]

    random_search.fit(X_train, y_train)

    score = random_search.score(X_test, y_test)

    best_scores.append(score)
    best_configurations.append({
        "hyper-parameters" : random_search.best_params_,
        "performance_estimate" : random_search.best_score_
    })
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END algorithm=auto, leaf_size=13223, n_neighbors=170, p=35102, weights=distance;, score=0.576 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=13223, n_neighbors=170, p=35102, weights=distance;, score=0.552 total time=   0.1s
# [CV 3/5] END algorithm=auto, leaf_size=13223, n_neighbors=170, p=35102, weights=distance;, score=0.552 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=13223, n_neighbors=170, p=35102, weights=distance;, score=0.538 total time=   0.3s
# [CV 5/5] END algorithm=auto, leaf_size=13223, n_neighbors=170, p=35102, weights=distance;, score=0.516 total time=   0.3s
# [CV 1/5] END algorithm=auto, leaf_size=89112, n_neighbors=161, p=28573, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=89112, n_neighbors=161, p=28573, weights=uniform;, score=0.427 total time=   0.6s
# [CV 3/5] END algorithm=auto, leaf_size=89112, n_neighbors=161, p=28573, weights=uniform;, score=0.424 total time=   0.5s
# [CV 4/5] END algorithm=auto, leaf_size=89112, n_neighbors=161, p=28573, weights=uniform;, score=0.424 total time=   0.4s
# [CV 5/5] END algorithm=auto, leaf_size=89112, n_neighbors=161, p=28573, weights=uniform;, score=0.425 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=95621, n_neighbors=218, p=75058, weights=distance;, score=0.576 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=95621, n_neighbors=218, p=75058, weights=distance;, score=0.556 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=95621, n_neighbors=218, p=75058, weights=distance;, score=0.556 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=95621, n_neighbors=218, p=75058, weights=distance;, score=0.538 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=95621, n_neighbors=218, p=75058, weights=distance;, score=0.516 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=7029, n_neighbors=10, p=48960, weights=uniform;, score=0.510 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=7029, n_neighbors=10, p=48960, weights=uniform;, score=0.521 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=7029, n_neighbors=10, p=48960, weights=uniform;, score=0.521 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=7029, n_neighbors=10, p=48960, weights=uniform;, score=0.528 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=7029, n_neighbors=10, p=48960, weights=uniform;, score=0.491 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=74314, n_neighbors=302, p=56567, weights=distance;, score=0.576 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=74314, n_neighbors=302, p=56567, weights=distance;, score=0.556 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=74314, n_neighbors=302, p=56567, weights=distance;, score=0.556 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=74314, n_neighbors=302, p=56567, weights=distance;, score=0.538 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=74314, n_neighbors=302, p=56567, weights=distance;, score=0.516 total time=   0.3s
# [CV 1/5] END algorithm=kd_tree, leaf_size=84014, n_neighbors=375, p=27153, weights=distance;, score=0.556 total time=   0.3s
# [CV 2/5] END algorithm=kd_tree, leaf_size=84014, n_neighbors=375, p=27153, weights=distance;, score=0.556 total time=   0.3s
# [CV 3/5] END algorithm=kd_tree, leaf_size=84014, n_neighbors=375, p=27153, weights=distance;, score=0.552 total time=   0.3s
# [CV 4/5] END algorithm=kd_tree, leaf_size=84014, n_neighbors=375, p=27153, weights=distance;, score=0.552 total time=   0.5s
# [CV 5/5] END algorithm=kd_tree, leaf_size=84014, n_neighbors=375, p=27153, weights=distance;, score=0.519 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=56653, n_neighbors=369, p=62948, weights=uniform;, score=0.427 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=56653, n_neighbors=369, p=62948, weights=uniform;, score=0.427 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=56653, n_neighbors=369, p=62948, weights=uniform;, score=0.424 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=56653, n_neighbors=369, p=62948, weights=uniform;, score=0.424 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=56653, n_neighbors=369, p=62948, weights=uniform;, score=0.425 total time=   0.3s
# [CV 1/5] END algorithm=brute, leaf_size=99379, n_neighbors=124, p=29625, weights=uniform;, score=0.427 total time=   0.4s
# [CV 2/5] END algorithm=brute, leaf_size=99379, n_neighbors=124, p=29625, weights=uniform;, score=0.427 total time=   0.3s
# [CV 3/5] END algorithm=brute, leaf_size=99379, n_neighbors=124, p=29625, weights=uniform;, score=0.424 total time=   0.2s
# [CV 4/5] END algorithm=brute, leaf_size=99379, n_neighbors=124, p=29625, weights=uniform;, score=0.427 total time=   0.3s
# [CV 5/5] END algorithm=brute, leaf_size=99379, n_neighbors=124, p=29625, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=15509, n_neighbors=370, p=13729, weights=distance;, score=0.583 total time=   0.3s
# [CV 2/5] END algorithm=brute, leaf_size=15509, n_neighbors=370, p=13729, weights=distance;, score=0.583 total time=   0.3s
# [CV 3/5] END algorithm=brute, leaf_size=15509, n_neighbors=370, p=13729, weights=distance;, score=0.562 total time=   0.4s
# [CV 4/5] END algorithm=brute, leaf_size=15509, n_neighbors=370, p=13729, weights=distance;, score=0.594 total time=   0.6s
# [CV 5/5] END algorithm=brute, leaf_size=15509, n_neighbors=370, p=13729, weights=distance;, score=0.544 total time=   0.7s
# [CV 1/5] END algorithm=kd_tree, leaf_size=59449, n_neighbors=52, p=36096, weights=uniform;, score=0.455 total time=   0.5s
# [CV 2/5] END algorithm=kd_tree, leaf_size=59449, n_neighbors=52, p=36096, weights=uniform;, score=0.472 total time=   0.4s
# [CV 3/5] END algorithm=kd_tree, leaf_size=59449, n_neighbors=52, p=36096, weights=uniform;, score=0.438 total time=   0.5s
# [CV 4/5] END algorithm=kd_tree, leaf_size=59449, n_neighbors=52, p=36096, weights=uniform;, score=0.462 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=59449, n_neighbors=52, p=36096, weights=uniform;, score=0.456 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=84176, n_neighbors=395, p=94835, weights=uniform;, score=0.427 total time=   0.4s
# [CV 2/5] END algorithm=auto, leaf_size=84176, n_neighbors=395, p=94835, weights=uniform;, score=0.427 total time=   0.4s
# [CV 3/5] END algorithm=auto, leaf_size=84176, n_neighbors=395, p=94835, weights=uniform;, score=0.424 total time=   0.3s
# [CV 4/5] END algorithm=auto, leaf_size=84176, n_neighbors=395, p=94835, weights=uniform;, score=0.424 total time=   0.3s
# [CV 5/5] END algorithm=auto, leaf_size=84176, n_neighbors=395, p=94835, weights=uniform;, score=0.425 total time=   0.4s
# [CV 1/5] END algorithm=kd_tree, leaf_size=8701, n_neighbors=89, p=91359, weights=distance;, score=0.580 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=8701, n_neighbors=89, p=91359, weights=distance;, score=0.562 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=8701, n_neighbors=89, p=91359, weights=distance;, score=0.556 total time=   0.3s
# [CV 4/5] END algorithm=kd_tree, leaf_size=8701, n_neighbors=89, p=91359, weights=distance;, score=0.542 total time=   0.3s
# [CV 5/5] END algorithm=kd_tree, leaf_size=8701, n_neighbors=89, p=91359, weights=distance;, score=0.519 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=1604, n_neighbors=261, p=94520, weights=distance;, score=0.576 total time=   0.5s
# [CV 2/5] END algorithm=kd_tree, leaf_size=1604, n_neighbors=261, p=94520, weights=distance;, score=0.559 total time=   0.4s
# [CV 3/5] END algorithm=kd_tree, leaf_size=1604, n_neighbors=261, p=94520, weights=distance;, score=0.556 total time=   0.3s
# [CV 4/5] END algorithm=kd_tree, leaf_size=1604, n_neighbors=261, p=94520, weights=distance;, score=0.538 total time=   0.3s
# [CV 5/5] END algorithm=kd_tree, leaf_size=1604, n_neighbors=261, p=94520, weights=distance;, score=0.519 total time=   0.4s
# [CV 1/5] END algorithm=kd_tree, leaf_size=72504, n_neighbors=173, p=39044, weights=distance;, score=0.576 total time=   0.4s
# [CV 2/5] END algorithm=kd_tree, leaf_size=72504, n_neighbors=173, p=39044, weights=distance;, score=0.556 total time=   0.4s
# [CV 3/5] END algorithm=kd_tree, leaf_size=72504, n_neighbors=173, p=39044, weights=distance;, score=0.552 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=72504, n_neighbors=173, p=39044, weights=distance;, score=0.542 total time=   0.3s
# [CV 5/5] END algorithm=kd_tree, leaf_size=72504, n_neighbors=173, p=39044, weights=distance;, score=0.516 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=48707, n_neighbors=39, p=80634, weights=distance;, score=0.587 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=48707, n_neighbors=39, p=80634, weights=distance;, score=0.562 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=48707, n_neighbors=39, p=80634, weights=distance;, score=0.556 total time=   0.1s
# [CV 4/5] END algorithm=ball_tree, leaf_size
total time=   0.1s
# [CV 1/5] END algorithm=ball_tree, leaf_size=92850, n_neighbors=422, p=56909, weights=distance;, score=0.576 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=92850, n_neighbors=422, p=56909, weights=distance;, score=0.556 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=92850, n_neighbors=422, p=56909, weights=distance;, score=0.556 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=92850, n_neighbors=422, p=56909, weights=distance;, score=0.538 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=92850, n_neighbors=422, p=56909, weights=distance;, score=0.516 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=90503, n_neighbors=344, p=1763, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=brute, leaf_size=90503, n_neighbors=344, p=1763, weights=uniform;, score=0.438 total time=   0.2s
# [CV 3/5] END algorithm=brute, leaf_size=90503, n_neighbors=344, p=1763, weights=uniform;, score=0.431 total time=   0.2s
# [CV 4/5] END algorithm=brute, leaf_size=90503, n_neighbors=344, p=1763, weights=uniform;, score=0.434 total time=   0.2s
# [CV 5/5] END algorithm=brute, leaf_size=90503, n_neighbors=344, p=1763, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=47606, n_neighbors=120, p=7012, weights=uniform;, score=0.438 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=47606, n_neighbors=120, p=7012, weights=uniform;, score=0.431 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=47606, n_neighbors=120, p=7012, weights=uniform;, score=0.434 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=47606, n_neighbors=120, p=7012, weights=uniform;, score=0.431 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=47606, n_neighbors=120, p=7012, weights=uniform;, score=0.432 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=52074, n_neighbors=488, p=24381, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=52074, n_neighbors=488, p=24381, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=52074, n_neighbors=488, p=24381, weights=uniform;, score=0.424 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=52074, n_neighbors=488, p=24381, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=52074, n_neighbors=488, p=24381, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=96953, n_neighbors=192, p=15591, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=96953, n_neighbors=192, p=15591, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=96953, n_neighbors=192, p=15591, weights=uniform;, score=0.424 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=96953, n_neighbors=192, p=15591, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=96953, n_neighbors=192, p=15591, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=23587, n_neighbors=22, p=58324, weights=uniform;, score=0.486 total time=   0.1s
# [CV 2/5] END algorithm=auto, leaf_size=23587, n_neighbors=22, p=58324, weights=uniform;, score=0.500 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=23587, n_neighbors=22, p=58324, weights=uniform;, score=0.500 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=23587, n_neighbors=22, p=58324, weights=uniform;, score=0.476 total time=   0.1s
# [CV 5/5] END algorithm=auto, leaf_size=23587, n_neighbors=22, p=58324, weights=uniform;, score=0.495 total time=   0.1s
# [CV 1/5] END algorithm=kd_tree, leaf_size=24419, n_neighbors=14, p=97765, weights=distance;, score=0.559 total time=   0.1s
# [CV 2/5] END algorithm=kd_tree, leaf_size=24419, n_neighbors=14, p=97765, weights=distance;, score=0.573 total time=   0.1s
# [CV 3/5] END algorithm=kd_tree, leaf_size=24419, n_neighbors=14, p=97765, weights=distance;, score=0.545 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=24419, n_neighbors=14, p=97765, weights=distance;, score=0.521 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=24419, n_neighbors=14, p=97765, weights=distance;, score=0.502 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=90627, n_neighbors=124, p=88589, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=90627, n_neighbors=124, p=88589, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=90627, n_neighbors=124, p=88589, weights=uniform;, score=0.424 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=90627, n_neighbors=124, p=88589, weights=uniform;, score=0.427 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=90627, n_neighbors=124, p=88589, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=34550, n_neighbors=137, p=82186, weights=distance;, score=0.601 total time=   0.2s
# [CV 2/5] END algorithm=brute, leaf_size=34550, n_neighbors=137, p=82186, weights=distance;, score=0.590 total time=   0.3s
# [CV 3/5] END algorithm=brute, leaf_size=34550, n_neighbors=137, p=82186, weights=distance;, score=0.597 total time=   0.2s
# [CV 4/5] END algorithm=brute, leaf_size=34550, n_neighbors=137, p=82186, weights=distance;, score=0.569 total time=   0.2s
# [CV 5/5] END algorithm=brute, leaf_size=34550, n_neighbors=137, p=82186, weights=distance;, score=0.551 total time=   0.1s
# [CV 1/5] END algorithm=kd_tree, leaf_size=77131, n_neighbors=26, p=61043, weights=distance;, score=0.583 total time=   0.1s
# [CV 2/5] END algorithm=kd_tree, leaf_size=77131, n_neighbors=26, p=61043, weights=distance;, score=0.556 total time=   0.1s
# [CV 3/5] END algorithm=kd_tree, leaf_size=77131, n_neighbors=26, p=61043, weights=distance;, score=0.549 total time=   0.1s
# [CV 4/5] END algorithm=kd_tree, leaf_size=77131, n_neighbors=26, p=61043, weights=distance;, score=0.528 total time=   0.1s
# [CV 5/5] END algorithm=kd_tree, leaf_size=77131, n_neighbors=26, p=61043, weights=distance;, score=0.519 total time=   0.1s
# [CV 1/5] END algorithm=auto, leaf_size=10375, n_neighbors=361, p=93365, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=10375, n_neighbors=361, p=93365, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=10375, n_neighbors=361, p=93365, weights=uniform;, score=0.424 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=10375, n_neighbors=361, p=93365, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=10375, n_neighbors=361, p=93365, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=89653, n_neighbors=348, p=63413, weights=distance;, score=0.576 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=89653, n_neighbors=348, p=63413, weights=distance;, score=0.556 total time=   0.1s
# [CV 3/5] END algorithm=auto, leaf_size=89653, n_neighbors=348, p=63413, weights=distance;, score=0.556 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size
total time=   0.1s
# [CV 3/5] END algorithm=ball_tree, leaf_size=41524, n_neighbors=261, p=86307, weights=distance;, score=0.497 total time=   0.1s
# [CV 4/5] END algorithm=ball_tree, leaf_size=41524, n_neighbors=261, p=86307, weights=distance;, score=0.545 total time=   0.1s
# [CV 5/5] END algorithm=ball_tree, leaf_size=41524, n_neighbors=261, p=86307, weights=distance;, score=0.557 total time=   0.1s
# [CV 1/5] END algorithm=ball_tree, leaf_size=13394, n_neighbors=411, p=79168, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=13394, n_neighbors=411, p=79168, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=13394, n_neighbors=411, p=79168, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=13394, n_neighbors=411, p=79168, weights=uniform;, score=0.424 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=13394, n_neighbors=411, p=79168, weights=uniform;, score=0.425 total time=   0.3s
# [CV 1/5] END algorithm=brute, leaf_size=61643, n_neighbors=377, p=59512, weights=distance;, score=0.569 total time=   0.3s
# [CV 2/5] END algorithm=brute, leaf_size=61643, n_neighbors=377, p=59512, weights=distance;, score=0.580 total time=   0.4s
# [CV 3/5] END algorithm=brute, leaf_size=61643, n_neighbors=377, p=59512, weights=distance;, score=0.569 total time=   0.3s
# [CV 4/5] END algorithm=brute, leaf_size=61643, n_neighbors=377, p=59512, weights=distance;, score=0.576 total time=   0.3s
# [CV 5/5] END algorithm=brute, leaf_size=61643, n_neighbors=377, p=59512, weights=distance;, score=0.603 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=12810, n_neighbors=206, p=54062, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=12810, n_neighbors=206, p=54062, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=12810, n_neighbors=206, p=54062, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=12810, n_neighbors=206, p=54062, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=12810, n_neighbors=206, p=54062, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=21017, n_neighbors=452, p=14241, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=21017, n_neighbors=452, p=14241, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=21017, n_neighbors=452, p=14241, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=21017, n_neighbors=452, p=14241, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=21017, n_neighbors=452, p=14241, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=17937, n_neighbors=136, p=90598, weights=distance;, score=0.569 total time=   0.1s
# [CV 2/5] END algorithm=brute, leaf_size=17937, n_neighbors=136, p=90598, weights=distance;, score=0.580 total time=   0.1s
# [CV 3/5] END algorithm=brute, leaf_size=17937, n_neighbors=136, p=90598, weights=distance;, score=0.569 total time=   0.1s
# [CV 4/5] END algorithm=brute, leaf_size=17937, n_neighbors=136, p=90598, weights=distance;, score=0.576 total time=   0.1s
# [CV 5/5] END algorithm=brute, leaf_size=17937, n_neighbors=136, p=90598, weights=distance;, score=0.603 total time=   0.1s
# [CV 1/5] END algorithm=auto, leaf_size=96723, n_neighbors=43, p=10182, weights=uniform;, score=0.483 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=96723, n_neighbors=43, p=10182, weights=uniform;, score=0.476 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=96723, n_neighbors=43, p=10182, weights=uniform;, score=0.486 total time=   0.1s
# [CV 4/5] END algorithm=auto, leaf_size=96723, n_neighbors=43, p=10182, weights=uniform;, score=0.479 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=96723, n_neighbors=43, p=10182, weights=uniform;, score=0.512 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=78670, n_neighbors=129, p=91849, weights=distance;, score=0.538 total time=   0.1s
# [CV 2/5] END algorithm=kd_tree, leaf_size=78670, n_neighbors=129, p=91849, weights=distance;, score=0.552 total time=   0.1s
# [CV 3/5] END algorithm=kd_tree, leaf_size=78670, n_neighbors=129, p=91849, weights=distance;, score=0.497 total time=   0.1s
# [CV 4/5] END algorithm=kd_tree, leaf_size=78670, n_neighbors=129, p=91849, weights=distance;, score=0.545 total time=   0.1s
# [CV 5/5] END algorithm=kd_tree, leaf_size=78670, n_neighbors=129, p=91849, weights=distance;, score=0.557 total time=   0.1s
# [CV 1/5] END algorithm=ball_tree, leaf_size=62631, n_neighbors=86, p=31751, weights=uniform;, score=0.441 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=62631, n_neighbors=86, p=31751, weights=uniform;, score=0.434 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=62631, n_neighbors=86, p=31751, weights=uniform;, score=0.431 total time=   0.1s
# [CV 4/5] END algorithm=ball_tree, leaf_size=62631, n_neighbors=86, p=31751, weights=uniform;, score=0.431 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=62631, n_neighbors=86, p=31751, weights=uniform;, score=0.425 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=68252, n_neighbors=143, p=5390, weights=uniform;, score=0.431 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=68252, n_neighbors=143, p=5390, weights=uniform;, score=0.434 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=68252, n_neighbors=143, p=5390, weights=uniform;, score=0.424 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=68252, n_neighbors=143, p=5390, weights=uniform;, score=0.431 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=68252, n_neighbors=143, p=5390, weights=uniform;, score=0.432 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=54125, n_neighbors=464, p=21041, weights=distance;, score=0.538 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=54125, n_neighbors=464, p=21041, weights=distance;, score=0.545 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=54125, n_neighbors=464, p=21041, weights=distance;, score=0.486 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=54125, n_neighbors=464, p=21041, weights=distance;, score=0.549 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size
weights=uniform;, score=0.424 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=57725, n_neighbors=216, p=44110, weights=distance;, score=0.500 total time=   0.1s
# [CV 2/5] END algorithm=auto, leaf_size=57725, n_neighbors=216, p=44110, weights=distance;, score=0.535 total time=   0.1s
# [CV 3/5] END algorithm=auto, leaf_size=57725, n_neighbors=216, p=44110, weights=distance;, score=0.569 total time=   0.1s
# [CV 4/5] END algorithm=auto, leaf_size=57725, n_neighbors=216, p=44110, weights=distance;, score=0.601 total time=   0.1s
# [CV 5/5] END algorithm=auto, leaf_size=57725, n_neighbors=216, p=44110, weights=distance;, score=0.556 total time=   0.1s
# [CV 1/5] END algorithm=kd_tree, leaf_size=61990, n_neighbors=45, p=74838, weights=distance;, score=0.507 total time=   0.1s
# [CV 2/5] END algorithm=kd_tree, leaf_size=61990, n_neighbors=45, p=74838, weights=distance;, score=0.542 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=61990, n_neighbors=45, p=74838, weights=distance;, score=0.587 total time=   0.1s
# [CV 4/5] END algorithm=kd_tree, leaf_size=61990, n_neighbors=45, p=74838, weights=distance;, score=0.608 total time=   0.1s
# [CV 5/5] END algorithm=kd_tree, leaf_size=61990, n_neighbors=45, p=74838, weights=distance;, score=0.562 total time=   0.1s
# [CV 1/5] END algorithm=auto, leaf_size=23582, n_neighbors=429, p=10930, weights=distance;, score=0.517 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=23582, n_neighbors=429, p=10930, weights=distance;, score=0.569 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=23582, n_neighbors=429, p=10930, weights=distance;, score=0.562 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=23582, n_neighbors=429, p=10930, weights=distance;, score=0.587 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=23582, n_neighbors=429, p=10930, weights=distance;, score=0.573 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=97776, n_neighbors=352, p=57688, weights=distance;, score=0.500 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=97776, n_neighbors=352, p=57688, weights=distance;, score=0.535 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=97776, n_neighbors=352, p=57688, weights=distance;, score=0.573 total time=   0.1s
# [CV 4/5] END algorithm=ball_tree, leaf_size=97776, n_neighbors=352, p=57688, weights=distance;, score=0.597 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=97776, n_neighbors=352, p=57688, weights=distance;, score=0.552 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=37772, n_neighbors=489, p=98048, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=37772, n_neighbors=489, p=98048, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=37772, n_neighbors=489, p=98048, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=37772, n_neighbors=489, p=98048, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=37772, n_neighbors=489, p=98048, weights=uniform;, score=0.424 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=89355, n_neighbors=80, p=55113, weights=uniform;, score=0.427 total time=   0.1s
# [CV 2/5] END algorithm=brute, leaf_size=89355, n_neighbors=80, p=55113, weights=uniform;, score=0.424 total time=   0.1s
# [CV 3/5] END algorithm=brute, leaf_size=89355, n_neighbors=80, p=55113, weights=uniform;, score=0.438 total time=   0.1s
# [CV 4/5] END algorithm=brute, leaf_size=89355, n_neighbors=80, p=55113, weights=uniform;, score=0.431 total time=   0.1s
# [CV 5/5] END algorithm=brute, leaf_size=89355, n_neighbors=80, p=55113, weights=uniform;, score=0.434 total time=   0.1s
# [CV 1/5] END algorithm=kd_tree, leaf_size=91292, n_neighbors=109, p=39727, weights=distance;, score=0.500 total time=   0.1s
# [CV 2/5] END algorithm=kd_tree, leaf_size=91292, n_neighbors=109, p=39727, weights=distance;, score=0.538 total time=   0.1s
# [CV 3/5] END algorithm=kd_tree, leaf_size=91292, n_neighbors=109, p=39727, weights=distance;, score=0.569 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=91292, n_neighbors=109, p=39727, weights=distance;, score=0.601 total time=   0.1s
# [CV 5/5] END algorithm=kd_tree, leaf_size=91292, n_neighbors=109, p=39727, weights=distance;, score=0.556 total time=   0.1s
# [CV 1/5] END algorithm=kd_tree, leaf_size=13908, n_neighbors=477, p=40654, weights=distance;, score=0.500 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=13908, n_neighbors=477, p=40654, weights=distance;, score=0.535 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=13908, n_neighbors=477, p=40654, weights=distance;, score=0.569 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=13908, n_neighbors=477, p=40654, weights=distance;, score=0.601 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=13908, n_neighbors=477, p=40654, weights=distance;, score=0.556 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=6998, n_neighbors=489, p=53239, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=6998, n_neighbors=489, p=53239, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=6998, n_neighbors=489, p=53239, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=6998, n_neighbors=489, p=53239, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=6998, n_neighbors=489, p=53239, weights=uniform;, score=0.424 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=61999, n_neighbors=183, p=40942, weights=uniform;, score=0.427 total time=   0.1s
# [CV 2/5] END algorithm=brute, leaf_size=61999, n_neighbors=183, p=40942, weights=uniform;, score=0.427 total time=   0.1s
# [CV 3/5] END algorithm=brute, leaf_size=61999, n_neighbors=183, p=40942, weights=uniform;, score=0.427 total time=   0.1s
# [CV 4/5] END algorithm=brute, leaf_size=61999, n_neighbors=183, p=40942, weights=uniform;, score=0.424 total time=   0.1s
# [CV 5/5] END algorithm=brute, leaf_size=61999, n_neighbors=183, p=40942, weights=uniform;, score=0.424 total time=   0.1s
# [CV 1/5] END algorithm=auto, leaf_size=73907, n_neighbors=49, p=62522, weights=distance;, score=0.500 total time=   0.1s
# [CV 2/5] END algorithm=auto, leaf_size=73907, n_neighbors=49, p=62522, weights=distance;, score=0.542 total time=   0.1s
# [CV 3/5] END algorithm=auto, leaf_size=73907, n_neighbors=49, p=62522, weights=distance;, score=0.580 total time=   0.1s
# [CV 4/5] END algorithm=auto, leaf_size=73907, n_neighbors=49, p=62522, weights=distance;, score=0.601 total time=   0.1s
# [CV 5/5] END algorithm=auto, leaf_size=73907, n_neighbors=49, p=62522, weights=distance;, score=0.556 total time=   0.1s
# [CV 1/5] END algorithm=auto, leaf_size=38791, n_neighbors=235, p=74205, weights=distance;, score=0.500 total time=   0.1s
# [CV 2/5] END algorithm=auto, leaf_size=38791, n_neighbors=235, p=74205, weights=distance;, score=0.535 total time=   0.1s
# [CV 3/5] END algorithm=auto, leaf_size=38791, n_neighbors=235, p=74205, weights=distance;, score=0.573 total time=   0.1s
# [CV 4/5] END algorithm=auto, leaf_size=38791, n_neighbors=235, p=74205, weights=distance;, score=0.597 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=38791, n_neighbors=235, p=74205, weights=distance;, score=0.552 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=89034, n_neighbors=328, p=96166, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=brute, leaf_size=89034, n_neighbors=328, p=96166, weights=uniform;, score=0.427 total time=   0.3s
# [CV 3/5] END algorithm=brute, leaf_size=89034, n_neighbors=328, p=96166, weights=uniform;, score=0.427 total time=   0.3s
# [CV 4/5] END algorithm=brute, leaf_size=89034, n_neighbors=328, p=96166, weights=uniform;, score=0.424 total time=   0.4s
# [CV 5/5] END algorithm=brute, leaf_size=89034, n_neighbors=328, p=96166, weights=uniform;, score=0.424 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=63093, n_neighbors=420, p=84719, weights=uniform;, score=0.427 total time=   0.3s
# [CV 2/5] END algorithm=auto, leaf_size=63093, n_neighbors=420, p=84719, weights=uniform;, score=0.427 total time=   0.3s
# [CV 3/5] END algorithm=auto, leaf_size=63093, n_neighbors=420, p=84719, weights=uniform;, score=0.427 total time=   0.3s
# [CV 4/5] END algorithm=auto, leaf_size=63093, n_neighbors=420, p=84719, weights=uniform;, score=0.424 total time=   0.3s
# [CV 5/5] END algorithm=auto, leaf_size=63093, n_neighbors=420, p=84719, weights=uniform;, score=0.424 total time=   0.3s
# [CV 1/5] END algorithm=kd_tree, leaf_size=35832, n_neighbors=62, p=955, weights=distance;, score=0.639 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=35832, n_neighbors=62, p=955, weights=distance;, score=0.608 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=35832, n_neighbors=62, p=955, weights=distance;, score=0.688 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=35832, n_neighbors=62, p=955, weights=distance;, score=0.677 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=35832, n_neighbors=62, p=955, weights=distance;, score=0.670 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=19258, n_neighbors=478, p=67514, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=kd_tree, leaf_size=19258, n_neighbors=478, p=67514, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=19258, n_neighbors=478, p=67514, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=19258, n_neighbors=478, p=67514, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=19258, n_neighbors=478, p=67514, weights=uniform;, score=0.424 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=54932, n_neighbors=392, p=67632, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=54932, n_neighbors=392, p=67632, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=54932, n_neighbors=392, p=67632, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=54932, n_neighbors=392, p=67632, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=54932, n_neighbors=392, p=67632, weights=uniform;, score=0.424 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=48233, n_neighbors=183, p=41184, weights=uniform;, score=0.427 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=48233, n_neighbors=183, p=41184, weights=uniform;, score=0.427 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=48233, n_neighbors=183, p=41184, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=48233, n_neighbors=183, p=41184, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=48233, n_neighbors=183, p=41184, weights=uniform;, score=0.424 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=3942, n_neighbors=454, p=70952, weights=distance;, score=0.542 total time=   0.2s
# [CV 2/5] END algorithm=brute, leaf_size=3942, n_neighbors=454, p=70952, weights=distance;, score=0.569 total time=   0.2s
# [CV 3/5] END algorithm=brute, leaf_size=3942, n_neighbors=454, p=70952, weights=distance;, score=0.615 total time=   0.2s
# [CV 4/5] END algorithm=brute, leaf_size=3942, n_neighbors=454, p=70952, weights=distance;, score=0.622 total time=   0.2s
# [CV 5/5] END algorithm=brute, leaf_size=3942, n_neighbors=454, p=70952, weights=distance;, score=0.583 total time=   0.2s
# [CV 1/5] END algorithm=brute, leaf_size=2507, n_neighbors=336, p=48344, weights=distance;, score=0.542 total time=   0.2s
# [CV 2/5] END algorithm=brute, leaf_size=2507, n_neighbors=336, p=48344, weights=distance;, score=0.569 total time=   0.1s
# [CV 3/5] END algorithm=brute, leaf_size=2507, n_neighbors=336, p=48344, weights=distance;, score=0.611 total time=   0.1s
# [CV 4/5] END algorithm=brute, leaf_size=2507, n_neighbors=336, p=48344, weights=distance;, score=0.625 total time=   0.1s
# [CV 5/5] END algorithm=brute, leaf_size=2507, n_neighbors=336, p=48344, weights=distance;, score=0.587 total time=   0.2s
# [CV 1/5] END algorithm=kd_tree, leaf_size=75346, n_neighbors=114, p=87884, weights=uniform;, score=0.427 total time=   0.1s
# [CV 2/5] END algorithm=kd_tree, leaf_size=75346, n_neighbors=114, p=87884, weights=uniform;, score=0.431 total time=   0.2s
# [CV 3/5] END algorithm=kd_tree, leaf_size=75346, n_neighbors=114, p=87884, weights=uniform;, score=0.427 total time=   0.2s
# [CV 4/5] END algorithm=kd_tree, leaf_size=75346, n_neighbors=114, p=87884, weights=uniform;, score=0.424 total time=   0.2s
# [CV 5/5] END algorithm=kd_tree, leaf_size=75346, n_neighbors=114, p=87884, weights=uniform;, score=0.420 total time=   0.1s
# [CV 1/5] END algorithm=auto, leaf_size=56843, n_neighbors=91, p=22185, weights=uniform;, score=0.431 total time=   0.2s
# [CV 2/5] END algorithm=auto, leaf_size=56843, n_neighbors=91, p=22185, weights=uniform;, score=0.431 total time=   0.2s
# [CV 3/5] END algorithm=auto, leaf_size=56843, n_neighbors=91, p=22185, weights=uniform;, score=0.431 total time=   0.2s
# [CV 4/5] END algorithm=auto, leaf_size=56843, n_neighbors=91, p=22185, weights=uniform;, score=0.427 total time=   0.2s
# [CV 5/5] END algorithm=auto, leaf_size=56843, n_neighbors=91, p=22185, weights=uniform;, score=0.431 total time=   0.2s
# [CV 1/5] END algorithm=auto, leaf_size=23984, n_neighbors=14, p=34750, weights=distance;, score=0.483 total time=   0.1s
# [CV 2/5] END algorithm=auto, leaf_size=23984, n_neighbors=14, p=34750, weights=distance;, score=0.531 total time=   0.1s
# [CV 3/5] END algorithm=auto, leaf_size=23984, n_neighbors=14, p=34750, weights=distance;, score=0.552 total time=   0.1s
# [CV 4/5] END algorithm=auto, leaf_size=23984, n_neighbors=14, p=34750, weights=distance;, score=0.583 total time=   0.1s
# [CV 5/5] END algorithm=auto, leaf_size=23984, n_neighbors=14, p=34750, weights=distance;, score=0.562 total time=   0.1s

# %%
best_configurations
# Out:
# [{'hyper-parameters': {'weights': 'distance',
#    'p': 1244,
#    'n_neighbors': 200,
#    'leaf_size': 84208,
#    'algorithm': 'kd_tree'},
#   'performance_estimate': 0.6275019357336431},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 59512,
#    'n_neighbors': 377,
#    'leaf_size': 61643,
#    'algorithm': 'brute'},
#   'performance_estimate': 0.5795852690669764},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 68305,
#    'n_neighbors': 36,
#    'leaf_size': 38690,
#    'algorithm': 'brute'},
#   'performance_estimate': 0.5927289005032907},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 61774,
#    'n_neighbors': 176,
#    'leaf_size': 42126,
#    'algorithm': 'brute'},
#   'performance_estimate': 0.5934668989547038},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 529,
#    'n_neighbors': 175,
#    'leaf_size': 7374,
#    'algorithm': 'kd_tree'},
#   'performance_estimate': 0.6608643050716221},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 92127,
#    'n_neighbors': 484,
#    'leaf_size': 47356,
#    'algorithm': 'brute'},
#   'performance_estimate': 0.6053184281842818},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 1539,
#    'n_neighbors': 154,
#    'leaf_size': 63441,
#    'algorithm': 'auto'},
#   'performance_estimate': 0.6240393921796361},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 993,
#    'n_neighbors': 171,
#    'leaf_size': 60784,
#    'algorithm': 'ball_tree'},
#   'performance_estimate': 0.6525261324041811},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 90116,
#    'n_neighbors': 115,
#    'leaf_size': 87328,
#    'algorithm': 'brute'},
#   'performance_estimate': 0.5816298877274487},
#  {'hyper-parameters': {'weights': 'distance',
#    'p': 955,
#    'n_neighbors': 62,
#    'leaf_size': 35832,
#    'algorithm': 'kd_tree'},
#   'performance_estimate': 0.65625}]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize =(10, 7))

plt.boxplot(best_scores)

plt.title("Model Performance Estimates")

plt.ylabel("Accuracy")

plt.show()

# %%
np.array(best_scores).mean()
# Out:
# 0.6260495283018866
