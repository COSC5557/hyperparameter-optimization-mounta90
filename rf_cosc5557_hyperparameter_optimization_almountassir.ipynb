# %% [markdown]
# # Hyperparameter Optimization
#
# For this exercise, we will have a look at Hyperparameter Optimization --
# instead of just choosing the best type of machine learning model, we also want
# to choose the best hyperparameter setting for a task. The end result (i.e. the
# predictive performance) is again not important; how you get there is.
#
# Your deliverable will be a report, written in a style that it
# would be suitable for inclusion in an academic paper as the "Experimental
# Setup" section or similar. If unsure, check an academic paper of your choice,
# for example [this one](https://www.eecs.uwyo.edu/~larsko/papers/pulatov_opening_2022-1.pdf). The
# level of detail should be higher than in a typical academic paper though. Your
# report should be at most five pages, including references and figures but
# excluding appendices. It should have the following structure:
# - Introduction: What problem are you solving, how are you going to solve it.
# - Dataset Description: Describe the data you're using, e.g. how many features and observations, what are you predicting, any missing values, etc.
# - Experimental Setup: What specifically are you doing to solve the problem, i.e.\ what programming languages and libraries, how are you processing the data, what machine learning algorithms are you considering and what hyperparameters and value ranges, what measures you are using to evaluate them, what hyperparameter optimization method you chose, etc.
# - Results: Description of what you observed, including plots. Compare
#   performance before and after tuning, and show the best configuration.
# - Code: Add the code you've used as a separate file.
#
# Your report must contain enough detail to reproduce what you did without the
# code. If in doubt, include more detail.
#
# There is no required format for the report. You could, for example, use an
# iPython notebook.
#
# ## Data and Setup
#
# We will have a look at the [Wine Quality
# dataset](https://archive-beta.ics.uci.edu/dataset/186/wine+quality). Choose the
# one that corresponds to your preference in wine. You may also use a dataset of
# your choice, for example one that's relevant to your research.
#
# Choose a small number of different machine learning algorithms and
# hyperparameters, along with value ranges, for each. You can use implementations
# of AutoML systems (e.g. auto-sklearn), scientific papers, or the documentation
# of the library you are using to determine the hyperparameters to tune and the
# value ranges. Note that there is not only a single way to do this, but define a
# reasonable space (e.g. don't include whether to turn on debug output, or random
# forests with 1,000,000 trees, or tune the loss function). Your hyperparameter
# search space should be so large that you cannot simply run a grid search.
#
# Determine the best machine learning algorithm and hyperparameter setting for
# your dataset. Make sure to optimize both the type of machine learning algorithm
# and the hyperparameters at the same time (do not first choose the best ML
# algorithm and then optimize its hyperparameters). Choose a suitable
# hyperparameter optimizer; you could also use several and e.g. compare the
# results achieved by random search and Bayesian optimization. Make sure that the
# way you evaluate model performance avoids bias and overfitting. You could use
# statistical tests to make this determination.
#
# ## Submission
#
# Add your report and code to this repository. Bonus points if you can set up a
# Github action to automatically run the code and generate the report!

# %% [markdown]
# ## Useful Resources :
# - "*Basics of HPO - Example and Practical Hints*" -From the AutoML Course Videos
# - https://www.youtube.com/watch?v=Gol_qOgRqfA
# - https://www.youtube.com/watch?v=0wUF_Ov8b0A&t=1058s

# %% [markdown]
# ## Importing the Dataset as a Pandas Dataframe

# %%
import pandas as pd
import numpy as np

# %%
red_wine_df = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X = red_wine_df.iloc[:, :-1]
y = red_wine_df['quality']

X.shape, y.shape
# Out:
# ((1599, 11), (1599,))

# %% [markdown]
# ## Importing our Models
#
# Continuing on from the "ML Algorithm Selection" exercise, we will use the same models to figure out the best model, for the red wine quality dataset, out of the following models :
# - Logistic Regression
# - K-Nearest Neighbors
# - Random Forest
# - Support Vector Classifier (SVM Classifier)
# - Decision Tree Classifier

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_classifier = RandomForestClassifier()

# %%
random_forest_classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ## Hyperparameter Optimization
#
# Methods Used :
# - Random Search
# - Bayesian Optimization

# %% [markdown]
# ### Bayesian Optimization

# %%
# Comment out this line to install the necessary library for Bayesian Optimization:
# !pip install baytune
# Out:
# Requirement already satisfied: baytune in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: copulas>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from baytune) (0.10.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.2.2)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.11.4)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.5.3)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from baytune) (4.66.2)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from copulas>=0.3.2->baytune) (5.15.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (3.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1->baytune) (1.16.0)

# %%
models = {
    'RF' : RandomForestClassifier
}

# %%
from sklearn.model_selection import cross_val_score

def scoring_function(model_name, hyperparameter_values):
    model_class = models[model_name]
    model_instance = model_class(**hyperparameter_values)
    scores = cross_val_score(
        cv=10,
        estimator=model_instance,
        X=X,
        y=y,
        scoring='accuracy',
    )

    return scores.mean()

# %%
from baytune.tuning import Tunable
from baytune.tuning import hyperparams as hp

# tunables = {
#     'RF': Tunable({
#         'n_estimators' : hp.IntHyperParam(min=50, max=1000, default=100),
#         'criterion' : hp.CategoricalHyperParam(['gini', 'entropy', 'log_loss'], default='gini'),
#         'max_depth': hp.IntHyperParam(min=1, max=20, default=5),
#         'min_samples_split': hp.IntHyperParam(min=2, max=10, default=2),
#         'min_samples_leaf': hp.IntHyperParam(min=1, max=10, default=1),
#         'min_weight_fraction_leaf': hp.FloatHyperParam(min=0.0, max=0.5, default=0.0),
#         'max_features': hp.CategoricalHyperParam(["sqrt", "log2", None], default='sqrt'),
#     })
# }

tunables = {
    'RF': Tunable({
        'n_estimators' : hp.IntHyperParam(min=50, max=1000, default=100),
        'criterion' : hp.CategoricalHyperParam(['gini', 'entropy', 'log_loss'], default='gini'),
        'max_depth': hp.IntHyperParam(min=1, max=100, default=5),
        'min_samples_split': hp.IntHyperParam(min=2, max=100, default=2),
        'min_samples_leaf': hp.IntHyperParam(min=1, max=100, default=1),
        'min_weight_fraction_leaf': hp.FloatHyperParam(min=0.0, max=0.5, default=0.0),
        'max_features': hp.CategoricalHyperParam(["sqrt", "log2", None], default='sqrt'),
    })
}

# %%
from baytune import BTBSession

session = BTBSession(
    tunables=tunables,
    scorer=scoring_function,
    verbose=True,
)

# %%
best_result = session.run(200)

best_result
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'id': 'a1d2be51a06316e212a0355b8645b5d4',
#  'name': 'RF',
#  'config': {'n_estimators': 185,
#   'criterion': 'gini',
#   'max_depth': 27,
#   'min_samples_split': 32,
#   'min_samples_leaf': 25,
#   'min_weight_fraction_leaf': 0.02226761651277137,
#   'max_features': 'log2'},
#  'score': 0.5978852201257862}

# %% [markdown]
# ### Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### Random Forest

# %%
from scipy.stats import uniform

# Define the hyperparameters:

n_estimators = range(50, 1000)
criterion = ['gini', 'entropy', 'log_loss']
max_depth = range(1, 100)
min_samples_split = range(2, 100)
min_samples_leaf = range(1, 100)
min_weight_fraction_leaf = uniform(scale=0.5)
max_features = ["sqrt", "log2", None]

# %%
# Construct the hyperparameter distribution:

hyperparameter_distribution = {
    "n_estimators": n_estimators,
    "criterion": criterion,
    "max_depth" : max_depth,
    "min_samples_split" : min_samples_split,
    "min_samples_leaf" : min_samples_leaf,
    "min_weight_fraction_leaf" : min_weight_fraction_leaf,
    "max_features" : max_features,
}

# %%
# Construct the "Random Search" object:

K_FOLDS = 10
ITERATIONS = 200
random_search = RandomizedSearchCV(random_forest_classifier, hyperparameter_distribution, cv=K_FOLDS, scoring='accuracy', n_iter=ITERATIONS, verbose=2)

# %%
# Run the "Random Search" on the dataset and on the hyperparameter distribution:

random_search.fit(X, y)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   2.8s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   5.2s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   4.0s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   3.4s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   2.2s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   2.6s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   1.8s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   1.8s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   1.8s
# [CV] END criterion=entropy, max_depth=79, max_features=log2, min_samples_leaf=68, min_samples_split=69, min_weight_fraction_leaf=0.4597191491279367, n_estimators=997; total time=   1.8s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.3s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.3s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.3s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.3s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.4s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.5s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.5s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.5s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.5s
# [CV] END criterion=entropy, max_depth=81, max_features=sqrt, min_samples_leaf=66, min_samples_split=7, min_weight_fraction_leaf=0.05365098909600996, n_estimators=125; total time=   0.4s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.2s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.3s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.3s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.2s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.9s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.4s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.3s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.3s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   2.3s
# [CV] END criterion=entropy, max_depth=21, max_features=log2, min_samples_leaf=69, min_samples_split=72, min_weight_fraction_leaf=0.029730905142348163, n_estimators=924; total time=   3.0s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.4s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.3s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.3s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.3s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.3s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.2s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.3s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.3s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.9s
# [CV] END criterion=entropy, max_depth=55, max_features=None, min_samples_leaf=33, min_samples_split=37, min_weight_fraction_leaf=0.15843568388993495, n_estimators=385; total time=   1.5s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.1s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.2s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.2s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.2s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.1s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.2s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.1s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.2s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.1s
# [CV] END criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=85, min_weight_fraction_leaf=0.26158824358355526, n_estimators=71; total time=   0.2s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   1.7s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   1.7s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   1.7s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   1.7s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   2.3s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   2.1s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   1.8s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   1.7s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   1.7s
# [CV] END criterion=entropy, max_depth=18, max_features=sqrt, min_samples_leaf=17, min_samples_split=62, min_weight_fraction_leaf=0.19677885793624544, n_estimators=796; total time=   2.3s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   1.0s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   0.9s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   1.1s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   1.0s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   0.7s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   0.7s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   0.7s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   0.7s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   0.7s
# [CV] END criterion=entropy, max_depth=24, max_features=None, min_samples_leaf=19, min_samples_split=84, min_weight_fraction_leaf=0.13242175270691808, n_estimators=205; total time=   0.7s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.6s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.4s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=22, min_samples_split=63, min_weight_fraction_leaf=0.2659510559322896, n_estimators=551; total time=   1.1s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.8s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.0s
# [CV] END criterion=gini, max_depth=64, max_features=log2, min_samples_leaf=10, min_samples_split=43, min_weight_fraction_leaf=0.20304222363454155, n_estimators=965; total time=   2.7s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=gini, max_depth=66, max_features=None, min_samples_leaf=13, min_samples_split=82, min_weight_fraction_leaf=0.43351442338230767, n_estimators=349; total time=   0.8s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=48, max_features=sqrt, min_samples_leaf=70, min_samples_split=15, min_weight_fraction_leaf=0.43276344823923324, n_estimators=152; total time=   0.5s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.3s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.3s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.3s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.4s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.3s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.4s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.3s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.7s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.8s
# [CV] END criterion=gini, max_depth=8, max_features=sqrt, min_samples_leaf=53, min_samples_split=49, min_weight_fraction_leaf=0.3775613203414519, n_estimators=716; total time=   1.4s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.8s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.0s
# [CV] END criterion=entropy, max_depth=68, max_features=sqrt, min_samples_leaf=45, min_samples_split=24, min_weight_fraction_leaf=0.2216684645717284, n_estimators=994; total time=   2.3s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.3s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.3s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.3s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.3s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.3s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.2s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.2s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.2s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.2s
# [CV] END criterion=gini, max_depth=25, max_features=None, min_samples_leaf=78, min_samples_split=86, min_weight_fraction_leaf=0.03302575871022834, n_estimators=52; total time=   0.2s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.9s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   2.1s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=entropy, max_depth=36, max_features=None, min_samples_leaf=89, min_samples_split=21, min_weight_fraction_leaf=0.19367882354048122, n_estimators=526; total time=   1.6s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.6s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   2.3s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=26, min_samples_split=82, min_weight_fraction_leaf=0.04614451542087955, n_estimators=587; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=49, max_features=log2, min_samples_leaf=85, min_samples_split=14, min_weight_fraction_leaf=0.37010484573202845, n_estimators=177; total time=   0.3s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.9s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=95, max_features=log2, min_samples_leaf=42, min_samples_split=39, min_weight_fraction_leaf=0.16645327241188074, n_estimators=397; total time=   0.8s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.6s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.9s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.4s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.4s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.4s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.4s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.4s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.4s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.4s
# [CV] END criterion=gini, max_depth=33, max_features=log2, min_samples_leaf=86, min_samples_split=3, min_weight_fraction_leaf=0.48097818628112454, n_estimators=729; total time=   1.9s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=63, min_samples_split=39, min_weight_fraction_leaf=0.412930177025275, n_estimators=620; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=17, max_features=sqrt, min_samples_leaf=94, min_samples_split=32, min_weight_fraction_leaf=0.41137319811378364, n_estimators=651; total time=   1.7s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.9s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.9s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=94, max_features=log2, min_samples_leaf=74, min_samples_split=97, min_weight_fraction_leaf=0.13615894378871002, n_estimators=681; total time=   1.5s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   2.0s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   2.2s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=56, min_samples_split=83, min_weight_fraction_leaf=0.2557099059156025, n_estimators=828; total time=   1.7s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   2.0s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   2.2s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   1.7s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   1.7s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   1.7s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   1.7s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   1.7s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   2.1s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   2.1s
# [CV] END criterion=entropy, max_depth=75, max_features=sqrt, min_samples_leaf=40, min_samples_split=61, min_weight_fraction_leaf=0.4537123184686555, n_estimators=901; total time=   1.7s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=53, max_features=log2, min_samples_leaf=78, min_samples_split=8, min_weight_fraction_leaf=0.07819302605135497, n_estimators=175; total time=   0.4s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   0.7s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   0.7s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   0.7s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   0.7s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   1.0s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   1.1s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   0.9s
# [CV] END criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=35, min_samples_split=25, min_weight_fraction_leaf=0.4729042304439776, n_estimators=377; total time=   0.7s
# ...
# [CV] END criterion=gini, max_depth=99, max_features=sqrt, min_samples_leaf=54, min_samples_split=28, min_weight_fraction_leaf=0.10198644449423233, n_estimators=927; total time=   2.1s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=26, max_features=sqrt, min_samples_leaf=57, min_samples_split=55, min_weight_fraction_leaf=0.32162960573698407, n_estimators=155; total time=   0.3s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.9s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.9s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.5s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.4s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.5s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.5s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.5s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.5s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   2.0s
# [CV] END criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=37, min_samples_split=48, min_weight_fraction_leaf=0.1225150213030548, n_estimators=667; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   2.0s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=65, max_features=sqrt, min_samples_leaf=49, min_samples_split=68, min_weight_fraction_leaf=0.4617648171888246, n_estimators=722; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=75, max_features=log2, min_samples_leaf=64, min_samples_split=59, min_weight_fraction_leaf=0.30372292840232845, n_estimators=515; total time=   1.0s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.3s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.4s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.4s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.4s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.4s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.4s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.8s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.7s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.4s
# [CV] END criterion=gini, max_depth=94, max_features=sqrt, min_samples_leaf=86, min_samples_split=7, min_weight_fraction_leaf=0.17064203672729833, n_estimators=652; total time=   1.4s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.1s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.2s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.1s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.1s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.1s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.2s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.6s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.3s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.1s
# [CV] END criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=17, min_samples_split=40, min_weight_fraction_leaf=0.18386656252055184, n_estimators=515; total time=   1.1s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   2.1s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   2.4s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=gini, max_depth=18, max_features=log2, min_samples_leaf=82, min_samples_split=18, min_weight_fraction_leaf=0.23899408169258723, n_estimators=934; total time=   1.9s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   2.0s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.9s
# [CV] END criterion=log_loss, max_depth=76, max_features=None, min_samples_leaf=35, min_samples_split=15, min_weight_fraction_leaf=0.011804969894712414, n_estimators=256; total time=   1.7s
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(), n_iter=200,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(1, 100),
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': range(1, 100),
#                                         'min_samples_split': range(2, 100),
#                                         'min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x79fa0bb3f4f0>,
#                                         'n_estimators': range(50, 1000)},
#                    scoring='accuracy', verbose=2)

# %%
# Check the results:

pd.DataFrame(random_search.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#      mean_test_score  std_test_score  \
# 0           0.550362        0.052027
# 1           0.572866        0.063503
# 2           0.575998        0.065332
# 3           0.560362        0.068849
# 4           0.564119        0.068248
# ..               ...             ...
# 195         0.556616        0.065341
# 196         0.572869        0.064637
# 197         0.566623        0.060012
# 198         0.563487        0.066890
# 199         0.572877        0.045588
#
#                                                 params
# 0    {'criterion': 'entropy', 'max_depth': 79, 'max...
# 1    {'criterion': 'entropy', 'max_depth': 81, 'max...
# 2    {'criterion': 'entropy', 'max_depth': 21, 'max...
# 3    {'criterion': 'entropy', 'max_depth': 55, 'max...
# 4    {'criterion': 'gini', 'max_depth': 16, 'max_fe...
# ..                                                 ...
# 195  {'criterion': 'log_loss', 'max_depth': 75, 'ma...
# 196  {'criterion': 'gini', 'max_depth': 94, 'max_fe...
# 197  {'criterion': 'entropy', 'max_depth': 92, 'max...
# 198  {'criterion': 'gini', 'max_depth': 18, 'max_fe...
# 199  {'criterion': 'log_loss', 'max_depth': 76, 'ma...
#
# [200 rows x 3 columns]

# %%
print(random_search.best_score_)
print(random_search.best_params_)
# Out:
# 0.5922641509433962
# {'criterion': 'entropy', 'max_depth': 95, 'max_features': 'log2', 'min_samples_leaf': 25, 'min_samples_split': 72, 'min_weight_fraction_leaf': 0.033151757479596144, 'n_estimators': 647}
