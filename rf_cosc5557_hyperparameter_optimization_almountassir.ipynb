# %% [markdown]
# # Hyperparameter Optimization
#
# For this exercise, we will have a look at Hyperparameter Optimization --
# instead of just choosing the best type of machine learning model, we also want
# to choose the best hyperparameter setting for a task. The end result (i.e. the
# predictive performance) is again not important; how you get there is.
#
# Your deliverable will be a report, written in a style that it
# would be suitable for inclusion in an academic paper as the "Experimental
# Setup" section or similar. If unsure, check an academic paper of your choice,
# for example [this one](https://www.eecs.uwyo.edu/~larsko/papers/pulatov_opening_2022-1.pdf). The
# level of detail should be higher than in a typical academic paper though. Your
# report should be at most five pages, including references and figures but
# excluding appendices. It should have the following structure:
# - Introduction: What problem are you solving, how are you going to solve it.
# - Dataset Description: Describe the data you're using, e.g. how many features and observations, what are you predicting, any missing values, etc.
# - Experimental Setup: What specifically are you doing to solve the problem, i.e.\ what programming languages and libraries, how are you processing the data, what machine learning algorithms are you considering and what hyperparameters and value ranges, what measures you are using to evaluate them, what hyperparameter optimization method you chose, etc.
# - Results: Description of what you observed, including plots. Compare
#   performance before and after tuning, and show the best configuration.
# - Code: Add the code you've used as a separate file.
#
# Your report must contain enough detail to reproduce what you did without the
# code. If in doubt, include more detail.
#
# There is no required format for the report. You could, for example, use an
# iPython notebook.
#
# ## Data and Setup
#
# We will have a look at the [Wine Quality
# dataset](https://archive-beta.ics.uci.edu/dataset/186/wine+quality). Choose the
# one that corresponds to your preference in wine. You may also use a dataset of
# your choice, for example one that's relevant to your research.
#
# Choose a small number of different machine learning algorithms and
# hyperparameters, along with value ranges, for each. You can use implementations
# of AutoML systems (e.g. auto-sklearn), scientific papers, or the documentation
# of the library you are using to determine the hyperparameters to tune and the
# value ranges. Note that there is not only a single way to do this, but define a
# reasonable space (e.g. don't include whether to turn on debug output, or random
# forests with 1,000,000 trees, or tune the loss function). Your hyperparameter
# search space should be so large that you cannot simply run a grid search.
#
# Determine the best machine learning algorithm and hyperparameter setting for
# your dataset. Make sure to optimize both the type of machine learning algorithm
# and the hyperparameters at the same time (do not first choose the best ML
# algorithm and then optimize its hyperparameters). Choose a suitable
# hyperparameter optimizer; you could also use several and e.g. compare the
# results achieved by random search and Bayesian optimization. Make sure that the
# way you evaluate model performance avoids bias and overfitting. You could use
# statistical tests to make this determination.
#
# ## Submission
#
# Add your report and code to this repository. Bonus points if you can set up a
# Github action to automatically run the code and generate the report!

# %% [markdown]
# ## Useful Resources :
# - "*Basics of HPO - Example and Practical Hints*" -From the AutoML Course Videos
# - https://www.youtube.com/watch?v=Gol_qOgRqfA
# - https://www.youtube.com/watch?v=0wUF_Ov8b0A&t=1058s

# %% [markdown]
# ## Importing the Dataset as a Pandas Dataframe

# %%
import pandas as pd
import numpy as np

# %%
red_wine_df = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X = red_wine_df.iloc[:, :-1]
y = red_wine_df['quality']

X.shape, y.shape
# Out:
# ((1599, 11), (1599,))

# %% [markdown]
# ## Importing our Models
#
# Continuing on from the "ML Algorithm Selection" exercise, we will use the same models to figure out the best model, for the red wine quality dataset, out of the following models :
# - Logistic Regression
# - K-Nearest Neighbors
# - Random Forest
# - Support Vector Classifier (SVM Classifier)
# - Decision Tree Classifier

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_classifier = RandomForestClassifier()

# %%
random_forest_classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ## Hyperparameter Optimization
#
# Methods Used :
# - Random Search
# - Bayesian Optimization

# %% [markdown]
# ### Bayesian Optimization

# %%
# Comment out this line to install the necessary library for Bayesian Optimization:
# !pip install baytune
# Out:
# Collecting baytune
#   Downloading baytune-0.5.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 kB 1.8 MB/s eta 0:00:00
# Collecting copulas>=0.3.2 (from baytune)
#   Downloading copulas-0.10.1-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.2.2)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.11.4)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from baytune) (1.5.3)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from baytune) (4.66.2)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from copulas>=0.3.2->baytune) (5.15.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->baytune) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->baytune) (3.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->copulas>=0.3.2->baytune) (24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1->baytune) (1.16.0)
# Installing collected packages: copulas, baytune
# Successfully installed baytune-0.5.0 copulas-0.10.1

# %%
models = {
    'RF' : RandomForestClassifier
}

# %%
from baytune.tuning import Tunable
from baytune.tuning import hyperparams as hp

tunables = {
    'RF': Tunable({
        'n_estimators' : hp.IntHyperParam(min=50, max=1000, default=100),
        'criterion' : hp.CategoricalHyperParam(['gini', 'entropy', 'log_loss'], default='gini'),
        'max_depth': hp.IntHyperParam(min=1, max=100, default=5),
        'min_samples_split': hp.IntHyperParam(min=2, max=100, default=2),
        'min_samples_leaf': hp.IntHyperParam(min=1, max=100, default=1),
        'min_weight_fraction_leaf': hp.FloatHyperParam(min=0.0, max=0.5, default=0.0),
        'max_features': hp.CategoricalHyperParam(["sqrt", "log2", None], default='sqrt'),
    })
}

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from baytune import BTBSession

inner_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=90)
outer_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=90)
best_configurations = []
best_scores = []

for train_index, test_index in outer_fold.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    def scoring_function(model_name, hyperparameter_values):
        model_class = models[model_name]
        model_instance = model_class(**hyperparameter_values)
        scores = cross_val_score(
            cv=inner_fold,
            estimator=model_instance,
            X=X_train,
            y=y_train,
            scoring='accuracy',
        )

        return scores.mean()

    session = BTBSession(
        tunables=tunables,
        scorer=scoring_function,
        verbose=True,
    )

    best_result = session.run(30)

    best_model_name = best_result['name']
    hyperparameters = best_result['config']
    best_model_class = models[best_model_name]
    model_instance = best_model_class(**hyperparameters)

    model_instance.fit(X_train, y_train)

    score = model_instance.score(X_test, y_test)

    best_scores.append(score)
    best_configurations.append({
        "hyper-parameters" : hyperparameters,
        "performance_estimate" : score
    })
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
for configuration in best_configurations:
  print(configuration)
  print("****************************************************")
  print("****************************************************")
# Out:
# {'hyper-parameters': {'n_estimators': 538, 'criterion': 'gini', 'max_depth': 21, 'min_samples_split': 12, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.01550215013681494, 'max_features': 'sqrt'}, 'performance_estimate': 0.6125}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 138, 'criterion': 'gini', 'max_depth': 29, 'min_samples_split': 36, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.003344935634825408, 'max_features': 'sqrt'}, 'performance_estimate': 0.675}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 118, 'criterion': 'gini', 'max_depth': 97, 'min_samples_split': 28, 'min_samples_leaf': 15, 'min_weight_fraction_leaf': 0.016829390357937124, 'max_features': 'sqrt'}, 'performance_estimate': 0.64375}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 102, 'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.018153370352828047, 'max_features': 'sqrt'}, 'performance_estimate': 0.575}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 561, 'criterion': 'gini', 'max_depth': 92, 'min_samples_split': 35, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.013822291275020437, 'max_features': 'sqrt'}, 'performance_estimate': 0.59375}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 85, 'criterion': 'gini', 'max_depth': 37, 'min_samples_split': 23, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.013196913741721827, 'max_features': 'sqrt'}, 'performance_estimate': 0.61875}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 807, 'criterion': 'gini', 'max_depth': 62, 'min_samples_split': 12, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.00651493108848572, 'max_features': 'sqrt'}, 'performance_estimate': 0.65}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 436, 'criterion': 'gini', 'max_depth': 37, 'min_samples_split': 3, 'min_samples_leaf': 11, 'min_weight_fraction_leaf': 0.011889316964451002, 'max_features': 'sqrt'}, 'performance_estimate': 0.65}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 179, 'criterion': 'gini', 'max_depth': 69, 'min_samples_split': 44, 'min_samples_leaf': 21, 'min_weight_fraction_leaf': 0.021064998623677944, 'max_features': 'sqrt'}, 'performance_estimate': 0.5875}
# ****************************************************
# ****************************************************
# {'hyper-parameters': {'n_estimators': 196, 'criterion': 'gini', 'max_depth': 35, 'min_samples_split': 8, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.009928231091893946, 'max_features': 'sqrt'}, 'performance_estimate': 0.6918238993710691}
# ****************************************************
# ****************************************************

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize =(10, 7))

plt.boxplot(best_scores)

plt.title("Model Performance Estimates")

plt.ylabel("Accuracy")

plt.show()

# %%
np.array(best_scores).mean()
# Out:
# 0.629807389937107

# %% [markdown]
# ### Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### Random Forest

# %%
from scipy.stats import uniform

# Define the hyperparameters:

n_estimators = range(50, 1000)
criterion = ['gini', 'entropy', 'log_loss']
max_depth = range(1, 100)
min_samples_split = range(2, 100)
min_samples_leaf = range(1, 100)
min_weight_fraction_leaf = uniform(scale=0.5)
max_features = ["sqrt", "log2", None]

# %%
# Construct the hyperparameter distribution:

hyperparameter_distribution = {
    "n_estimators": n_estimators,
    "criterion": criterion,
    "max_depth" : max_depth,
    "min_samples_split" : min_samples_split,
    "min_samples_leaf" : min_samples_leaf,
    "min_weight_fraction_leaf" : min_weight_fraction_leaf,
    "max_features" : max_features,
}

# %%
from sklearn.model_selection import StratifiedKFold

inner_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=90)
outer_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=90)

ITERATIONS = 50
random_search = RandomizedSearchCV(
    random_forest_classifier,
    hyperparameter_distribution,
    cv=inner_fold,
    scoring='accuracy',
    n_iter=ITERATIONS,
    verbose=4
)

best_configurations = []
best_scores = []

for train_index, test_index in outer_fold.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    random_search.fit(X_train, y_train)

    score = random_search.score(X_test, y_test)

    best_scores.append(score)
    best_configurations.append({
        "hyper-parameters" : random_search.best_params_,
        "performance_estimate" : score
    })
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=log_loss, max_depth=52, max_features=log2, min_samples_leaf=25, min_samples_split=43, min_weight_fraction_leaf=0.4451355395616356, n_estimators=105;, score=0.559 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=52, max_features=log2, min_samples_leaf=25, min_samples_split=43, min_weight_fraction_leaf=0.4451355395616356, n_estimators=105;, score=0.583 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=52, max_features=log2, min_samples_leaf=25, min_samples_split=43, min_weight_fraction_leaf=0.4451355395616356, n_estimators=105;, score=0.562 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=52, max_features=log2, min_samples_leaf=25, min_samples_split=43, min_weight_fraction_leaf=0.4451355395616356, n_estimators=105;, score=0.545 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=52, max_features=log2, min_samples_leaf=25, min_samples_split=43, min_weight_fraction_leaf=0.4451355395616356, n_estimators=105;, score=0.540 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=96, max_features=log2, min_samples_leaf=6, min_samples_split=25, min_weight_fraction_leaf=0.3601746811021956, n_estimators=586;, score=0.573 total time=   2.4s
# [CV 2/5] END criterion=gini, max_depth=96, max_features=log2, min_samples_leaf=6, min_samples_split=25, min_weight_fraction_leaf=0.3601746811021956, n_estimators=586;, score=0.594 total time=   3.3s
# [CV 3/5] END criterion=gini, max_depth=96, max_features=log2, min_samples_leaf=6, min_samples_split=25, min_weight_fraction_leaf=0.3601746811021956, n_estimators=586;, score=0.569 total time=   2.1s
# [CV 4/5] END criterion=gini, max_depth=96, max_features=log2, min_samples_leaf=6, min_samples_split=25, min_weight_fraction_leaf=0.3601746811021956, n_estimators=586;, score=0.562 total time=   2.4s
# [CV 5/5] END criterion=gini, max_depth=96, max_features=log2, min_samples_leaf=6, min_samples_split=25, min_weight_fraction_leaf=0.3601746811021956, n_estimators=586;, score=0.547 total time=   2.3s
# [CV 1/5] END criterion=gini, max_depth=14, max_features=sqrt, min_samples_leaf=33, min_samples_split=34, min_weight_fraction_leaf=0.45331274585444337, n_estimators=755;, score=0.566 total time=   3.5s
# [CV 2/5] END criterion=gini, max_depth=14, max_features=sqrt, min_samples_leaf=33, min_samples_split=34, min_weight_fraction_leaf=0.45331274585444337, n_estimators=755;, score=0.580 total time=   4.4s
# [CV 3/5] END criterion=gini, max_depth=14, max_features=sqrt, min_samples_leaf=33, min_samples_split=34, min_weight_fraction_leaf=0.45331274585444337, n_estimators=755;, score=0.566 total time=   3.4s
# [CV 4/5] END criterion=gini, max_depth=14, max_features=sqrt, min_samples_leaf=33, min_samples_split=34, min_weight_fraction_leaf=0.45331274585444337, n_estimators=755;, score=0.535 total time=   2.8s
# [CV 5/5] END criterion=gini, max_depth=14, max_features=sqrt, min_samples_leaf=33, min_samples_split=34, min_weight_fraction_leaf=0.45331274585444337, n_estimators=755;, score=0.530 total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=42, max_features=sqrt, min_samples_leaf=79, min_samples_split=65, min_weight_fraction_leaf=0.38724238992046683, n_estimators=417;, score=0.569 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=42, max_features=sqrt, min_samples_leaf=79, min_samples_split=65, min_weight_fraction_leaf=0.38724238992046683, n_estimators=417;, score=0.590 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=42, max_features=sqrt, min_samples_leaf=79, min_samples_split=65, min_weight_fraction_leaf=0.38724238992046683, n_estimators=417;, score=0.580 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=42, max_features=sqrt, min_samples_leaf=79, min_samples_split=65, min_weight_fraction_leaf=0.38724238992046683, n_estimators=417;, score=0.562 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=42, max_features=sqrt, min_samples_leaf=79, min_samples_split=65, min_weight_fraction_leaf=0.38724238992046683, n_estimators=417;, score=0.540 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=42, min_weight_fraction_leaf=0.3409801749619278, n_estimators=673;, score=0.566 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=42, min_weight_fraction_leaf=0.3409801749619278, n_estimators=673;, score=0.583 total time=   1.3s
# [CV 3/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=42, min_weight_fraction_leaf=0.3409801749619278, n_estimators=673;, score=0.556 total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=42, min_weight_fraction_leaf=0.3409801749619278, n_estimators=673;, score=0.562 total time=   1.3s
# [CV 5/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=42, min_weight_fraction_leaf=0.3409801749619278, n_estimators=673;, score=0.547 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=93, max_features=sqrt, min_samples_leaf=29, min_samples_split=19, min_weight_fraction_leaf=0.24280370288629555, n_estimators=198;, score=0.562 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=93, max_features=sqrt, min_samples_leaf=29, min_samples_split=19, min_weight_fraction_leaf=0.24280370288629555, n_estimators=198;, score=0.611 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=93, max_features=sqrt, min_samples_leaf=29, min_samples_split=19, min_weight_fraction_leaf=0.24280370288629555, n_estimators=198;, score=0.569 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=93, max_features=sqrt, min_samples_leaf=29, min_samples_split=19, min_weight_fraction_leaf=0.24280370288629555, n_estimators=198;, score=0.597 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=93, max_features=sqrt, min_samples_leaf=29, min_samples_split=19, min_weight_fraction_leaf=0.24280370288629555, n_estimators=198;, score=0.561 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=83, max_features=None, min_samples_leaf=47, min_samples_split=12, min_weight_fraction_leaf=0.3910231796179128, n_estimators=193;, score=0.552 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=83, max_features=None, min_samples_leaf=47, min_samples_split=12, min_weight_fraction_leaf=0.3910231796179128, n_estimators=193;, score=0.597 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=83, max_features=None, min_samples_leaf=47, min_samples_split=12, min_weight_fraction_leaf=0.3910231796179128, n_estimators=193;, score=0.556 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=83, max_features=None, min_samples_leaf=47, min_samples_split=12, min_weight_fraction_leaf=0.3910231796179128, n_estimators=193;, score=0.556 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=83, max_features=None, min_samples_leaf=47, min_samples_split=12, min_weight_fraction_leaf=0.3910231796179128, n_estimators=193;, score=0.551 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=48, min_samples_split=31, min_weight_fraction_leaf=0.2556603122340161, n_estimators=568;, score=0.601 total time=   1.2s
# [CV 2/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=48, min_samples_split=31, min_weight_fraction_leaf=0.2556603122340161, n_estimators=568;, score=0.608 total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=48, min_samples_split=31, min_weight_fraction_leaf=0.2556603122340161, n_estimators=568;, score=0.556 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=48, min_samples_split=31, min_weight_fraction_leaf=0.2556603122340161, n_estimators=568;, score=0.576 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=48, min_samples_split=31, min_weight_fraction_leaf=0.2556603122340161, n_estimators=568;, score=0.561 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=26, min_samples_split=8, min_weight_fraction_leaf=0.1799733329127225, n_estimators=603;, score=0.576 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=26, min_samples_split=8, min_weight_fraction_leaf=0.1799733329127225, n_estimators=603;, score=0.618 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=26, min_samples_split=8, min_weight_fraction_leaf=0.1799733329127225, n_estimators=603;, score=0.583 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=26, min_samples_split=8, min_weight_fraction_leaf=0.1799733329127225, n_estimators=603;, score=0.583 total time=   1.9s
# [CV 5/5] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=26, min_samples_split=8, min_weight_fraction_leaf=0.1799733329127225, n_estimators=603;, score=0.557 total time=   1.6s
# [CV 1/5] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=79, min_samples_split=79, min_weight_fraction_leaf=0.3298175697510603, n_estimators=887;, score=0.576 total time=   1.7s
# [CV 2/5] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=79, min_samples_split=79, min_weight_fraction_leaf=0.3298175697510603, n_estimators=887;, score=0.601 total time=   1.7s
# [CV 3/5] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=79, min_samples_split=79, min_weight_fraction_leaf=0.3298175697510603, n_estimators=887;, score=0.569 total time=   1.7s
# [CV 4/5] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=79, min_samples_split=79, min_weight_fraction_leaf=0.3298175697510603, n_estimators=887;, score=0.556 total time=   1.6s
# [CV 5/5] END criterion=gini, max_depth=73, max_features=sqrt, min_samples_leaf=79, min_samples_split=79, min_weight_fraction_leaf=0.3298175697510603, n_estimators=887;, score=0.540 total time=   1.6s
# [CV 1/5] END criterion=gini, max_depth=46, max_features=None, min_samples_leaf=74, min_samples_split=70, min_weight_fraction_leaf=0.3418774612181954, n_estimators=924;, score=0.552 total time=   2.6s
# [CV 2/5] END criterion=gini, max_depth=46, max_features=None, min_samples_leaf=74, min_samples_split=70, min_weight_fraction_leaf=0.3418774612181954, n_estimators=924;, score=0.590 total time=   2.3s
# [CV 3/5] END criterion=gini, max_depth=46, max_features=None, min_samples_leaf=74, min_samples_split=70, min_weight_fraction_leaf=0.3418774612181954, n_estimators=924;, score=0.556 total time=   2.1s
# [CV 4/5] END criterion=gini, max_depth=46, max_features=None, min_samples_leaf=74, min_samples_split=70, min_weight_fraction_leaf=0.3418774612181954, n_estimators=924;, score=0.556 total time=   2.0s
# [CV 5/5] END criterion=gini, max_depth=46, max_features=None, min_samples_leaf=74, min_samples_split=70, min_weight_fraction_leaf=0.3418774612181954, n_estimators=924;, score=0.547 total time=   2.1s
# [CV 1/5] END criterion=gini, max_depth=15, max_features=None, min_samples_leaf=21, min_samples_split=53, min_weight_fraction_leaf=0.007467177973771055, n_estimators=990;, score=0.618 total time=   5.1s
# [CV 2/5] END criterion=gini, max_depth=15, max_features=None, min_samples_leaf=21, min_samples_split=53, min_weight_fraction_leaf=0.007467177973771055, n_estimators=990;, score=0.618 total time=   4.3s
# [CV 3/5] END criterion=gini, max_depth=15, max_features=None, min_samples_leaf=21, min_samples_split=53, min_weight_fraction_leaf=0.007467177973771055, n_estimators=990;, score=0.656 total time=   4.3s
# [CV 4/5] END criterion=gini, max_depth=15, max_features=None, min_samples_leaf=21, min_samples_split=53, min_weight_fraction_leaf=0.007467177973771055, n_estimators=990;, score=0.601 total time=   5.0s
# [CV 5/5] END criterion=gini, max_depth=15, max_features=None, min_samples_leaf=21, min_samples_split=53, min_weight_fraction_leaf=0.007467177973771055, n_estimators=990;, score=0.606 total time=   4.3s
# [CV 1/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=61, min_samples_split=71, min_weight_fraction_leaf=0.26764459890439696, n_estimators=955;, score=0.552 total time=   2.4s
# [CV 2/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=61, min_samples_split=71, min_weight_fraction_leaf=0.26764459890439696, n_estimators=955;, score=0.594 total time=   2.7s
# [CV 3/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=61, min_samples_split=71, min_weight_fraction_leaf=0.26764459890439696, n_estimators=955;, score=0.535 total time=   3.0s
# [CV 4/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=61, min_samples_split=71, min_weight_fraction_leaf=0.26764459890439696, n_estimators=955;, score=0.538 total time=   2.4s
# [CV 5/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=61, min_samples_split=71, min_weight_fraction_leaf=0.26764459890439696, n_estimators=955;, score=0.547 total time=   2.4s
# [CV 1/5] END criterion=log_loss, max_depth=94, max_features=log2, min_samples_leaf=51, min_samples_split=84, min_weight_fraction_leaf=0.21666338426884202, n_estimators=345;, score=0.587 total time=   0.7s
# [CV 2/5] END criterion=log_loss, max_depth=94, max_features=log2, min_samples_leaf=51, min_samples_split=84, min_weight_fraction_leaf=0.21666338426884202, n_estimators=345;, score=0.622 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=94, max_features=log2, min_samples_leaf=51, min_samples_split=84, min_weight_fraction_leaf=0.21666338426884202, n_estimators=345;, score=0.562 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=94, max_features=log2, min_samples_leaf=51, min_samples_split=84, min_weight_fraction_leaf=0.21666338426884202, n_estimators=345;, score=0.587 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=94, max_features=log2, min_samples_leaf=51, min_samples_split=84, min_weight_fraction_leaf=0.21666338426884202, n_estimators=345;, score=0.571 total time=   1.3s
# [CV 1/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=86, min_samples_split=39, min_weight_fraction_leaf=0.15111415288996205, n_estimators=932;, score=0.559 total time=   3.6s
# [CV 2/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=86, min_samples_split=39, min_weight_fraction_leaf=0.15111415288996205, n_estimators=932;, score=0.590 total time=   2.8s
# [CV 3/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=86, min_samples_split=39, min_weight_fraction_leaf=0.15111415288996205, n_estimators=932;, score=0.562 total time=   2.8s
# [CV 4/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=86, min_samples_split=39, min_weight_fraction_leaf=0.15111415288996205, n_estimators=932;, score=0.573 total time=   2.9s
# [CV 5/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=86, min_samples_split=39, min_weight_fraction_leaf=0.15111415288996205, n_estimators=932;, score=0.557 total time=   3.7s
# [CV 1/5] END criterion=log_loss, max_depth=8, max_features=None, min_samples_leaf=81, min_samples_split=14, min_weight_fraction_leaf=0.2171261099422171, n_estimators=819;, score=0.552 total time=   2.2s
# [CV 2/5] END criterion=log_loss, max_depth=8, max_features=None, min_samples_leaf=81, min_samples_split=14, min_weight_fraction_leaf=0.2171261099422171, n_estimators=819;, score=0.587 total time=   2.2s
# [CV 3/5] END criterion=log_loss, max_depth=8, max_features=None, min_samples_leaf=81, min_samples_split=14, min_weight_fraction_leaf=0.2171261099422171, n_estimators=819;, score=0.542 total time=   2.1s
# [CV 4/5] END criterion=log_loss, max_depth=8, max_features=None, min_samples_leaf=81, min_samples_split=14, min_weight_fraction_leaf=0.2171261099422171, n_estimators=819;, score=0.545 total time=   2.2s
# [CV 5/5] END criterion=log_loss, max_depth=8, max_features=None, min_samples_leaf=81, min_samples_split=14, min_weight_fraction_leaf=0.2171261099422171, n_estimators=819;, score=0.547 total time=   2.9s
# [CV 1/5] END criterion=log_loss, max_depth=41, max_features=None, min_samples_leaf=80, min_samples_split=90, min_weight_fraction_leaf=0.3662692470604267, n_estimators=470;, score=0.549 total time=   1.1s
# [CV 2/5] END criterion=log_loss, max_depth=41, max_features=None, min_samples_leaf=80, min_samples_split=90, min_weight_fraction_leaf=0.3662692470604267, n_estimators=470;, score=0.594 total time=   1.0s
# [CV 3/5] END criterion=log_loss, max_depth=41, max_features=None, min_samples_leaf=80, min_samples_split=90, min_weight_fraction_leaf=0.3662692470604267, n_estimators=470;, score=0.542 total time=   1.0s
# [CV 4/5] END criterion=log_loss, max_depth=41, max_features=None, min_samples_leaf=80, min_samples_split=90, min_weight_fraction_leaf=0.3662692470604267, n_estimators=470;, score=0.542 total time=   1.0s
# [CV 5/5] END criterion=log_loss, max_depth=41, max_features=None, min_samples_leaf=80, min_samples_split=90, min_weight_fraction_leaf=0.3662692470604267, n_estimators=470;, score=0.533 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=81, min_weight_fraction_leaf=0.3791263473458479, n_estimators=868;, score=0.552 total time=   1.6s
# [CV 2/5] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=81, min_weight_fraction_leaf=0.3791263473458479, n_estimators=868;, score=0.576 total time=   1.6s
# [CV 3/5] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=81, min_weight_fraction_leaf=0.3791263473458479, n_estimators=868;, score=0.552 total time=   1.8s
# [CV 4/5] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=81, min_weight_fraction_leaf=0.3791263473458479, n_estimators=868;, score=0.545 total time=   2.3s
# [CV 5/5] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=81, min_weight_fraction_leaf=0.3791263473458479, n_estimators=868;, score=0.551 total time=   1.6s
# [CV 1/5] END criterion=log_loss, max_depth=13, max_features=log2, min_samples_leaf=74, min_samples_split=99, min_weight_fraction_leaf=0.21499873058048002, n_estimators=359;, score=0.590 total time=   0.8s
# [CV 2/5] END criterion=log_loss, max_depth=13, max_features=log2, min_samples_leaf=74, min_samples_split=99, min_weight_fraction_leaf=0.21499873058048002, n_estimators=359;, score=0.611 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=13, max_features=log2, min_samples_leaf=74, min_samples_split=99, min_weight_fraction_leaf=0.21499873058048002, n_estimators=359;, score=0.556 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=13, max_features=log2, min_samples_leaf=74, min_samples_split=99, min_weight_fraction_leaf=0.21499873058048002, n_estimators=359;, score=0.576 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=13, max_features=log2, min_samples_leaf=74, min_samples_split=99, min_weight_fraction_leaf=0.21499873058048002, n_estimators=359;, score=0.564 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=44, max_features=None, min_samples_leaf=30, min_samples_split=43, min_weight_fraction_leaf=0.044638817781765094, n_estimators=895;, score=0.622 total time=   4.2s
# [CV 2/5] END criterion=entropy, max_depth=44, max_features=None, min_samples_leaf=30, min_samples_split=43, min_weight_fraction_leaf=0.044638817781765094, n_estimators=895;, score=0.601 total time=   4.9s
# [CV 3/5] END criterion=entropy, max_depth=44, max_features=None, min_samples_leaf=30, min_samples_split=43, min_weight_fraction_leaf=0.044638817781765094, n_estimators=895;, score=0.622 total time=   4.1s
# [CV 4/5] END criterion=entropy, max_depth=44, max_features=None, min_samples_leaf=30, min_samples_split=43, min_weight_fraction_leaf=0.044638817781765094, n_estimators=895;, score=0.597 total time=   4.4s
# [CV 5/5] END criterion=entropy, max_depth=44, max_features=None, min_samples_leaf=30, min_samples_split=43, min_weight_fraction_leaf=0.044638817781765094, n_estimators=895;, score=0.578 total time=   4.8s
# [CV 1/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=71, min_samples_split=81, min_weight_fraction_leaf=0.2688330771435896, n_estimators=258;, score=0.552 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=71, min_samples_split=81, min_weight_fraction_leaf=0.2688330771435896, n_estimators=258;, score=0.594 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=71, min_samples_split=81, min_weight_fraction_leaf=0.2688330771435896, n_estimators=258;, score=0.531 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=71, min_samples_split=81, min_weight_fraction_leaf=0.2688330771435896, n_estimators=258;, score=0.538 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=71, min_samples_split=81, min_weight_fraction_leaf=0.2688330771435896, n_estimators=258;, score=0.547 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=74, max_features=None, min_samples_leaf=17, min_samples_split=95, min_weight_fraction_leaf=0.4303671390159979, n_estimators=633;, score=0.552 total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=74, max_features=None, min_samples_leaf=17, min_samples_split=95, min_weight_fraction_leaf=0.4303671390159979, n_estimators=633;, score=0.597 total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=74, max_features=None, min_samples_leaf=17, min_samples_split=95, min_weight_fraction_leaf=0.4303671390159979, n_estimators=633;, score=0.559 total time=   1.6s
# [CV 4/5] END criterion=gini, max_depth=74, max_features=None, min_samples_leaf=17, min_samples_split=95, min_weight_fraction_leaf=0.4303671390159979, n_estimators=633;, score=0.556 total time=   2.1s
# [CV 5/5] END criterion=gini, max_depth=74, max_features=None, min_samples_leaf=17, min_samples_split=95, min_weight_fraction_leaf=0.4303671390159979, n_estimators=633;, score=0.547 total time=   1.4s
# [CV 1/5] END criterion=entropy, max_depth=98, max_features=log2, min_samples_leaf=74, min_samples_split=6, min_weight_fraction_leaf=0.17670918586763595, n_estimators=990;, score=0.583 total time=   2.0s
# [CV 2/5] END criterion=entropy, max_depth=98, max_features=log2, min_samples_leaf=74, min_samples_split=6, min_weight_fraction_leaf=0.17670918586763595, n_estimators=990;, score=0.622 total time=   2.1s
# [CV 3/5] END criterion=entropy, max_depth=98, max_features=log2, min_samples_leaf=74, min_samples_split=6, min_weight_fraction_leaf=0.17670918586763595, n_estimators=990;, score=0.566 total time=   2.0s
# [CV 4/5] END criterion=entropy, max_depth=98, max_features=log2, min_samples_leaf=74, min_samples_split=6, min_weight_fraction_leaf=0.17670918586763595, n_estimators=990;, score=0.583 total time=   2.0s
# [CV 5/5] END criterion=entropy, max_depth=98, max_features=log2, min_samples_leaf=74, min_samples_split=6, min_weight_fraction_leaf=0.17670918586763595, n_estimators=990;, score=0.564 total time=   2.9s
# [CV 1/5] END criterion=log_loss, max_depth=67, max_features=sqrt, min_samples_leaf=82, min_samples_split=73, min_weight_fraction_leaf=0.14609727784037324, n_estimators=187;, score=0.583 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=67, max_features=sqrt, min_samples_leaf=82, min_samples_split=73, min_weight_fraction_leaf=0.14609727784037324, n_estimators=187;, score=0.604 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=67, max_features=sqrt, min_samples_leaf=82, min_samples_split=73, min_weight_fraction_leaf=0.14609727784037324, n_estimators=187;, score=0.573 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=67, max_features=sqrt, min_samples_leaf=82, min_samples_split=73, min_weight_fraction_leaf=0.14609727784037324, n_estimators=187;, score=0.583 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=67, max_features=sqrt, min_samples_leaf=82, min_samples_split=73, min_weight_fraction_leaf=0.14609727784037324, n_estimators=187;, score=0.561 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=58, max_features=log2, min_samples_leaf=46, min_samples_split=57, min_weight_fraction_leaf=0.34690889474134134, n_estimators=802;, score=0.559 total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=58, max_features=log2, min_samples_leaf=46, min_samples_split=57, min_weight_fraction_leaf=0.34690889474134134, n_estimators=802;, score=0.590 total time=   1.5s
# [CV 3/5] END criterion=entropy, max_depth=58, max_features=log2, min_samples_leaf=46, min_samples_split=57, min_weight_fraction_leaf=0.34690889474134134, n_estimators=802;, score=0.556 total time=   1.5s
# [CV 4/5] END criterion=entropy, max_depth=58, max_features=log2, min_samples_leaf=46, min_samples_split=57, min_weight_fraction_leaf=0.34690889474134134, n_estimators=802;, score=0.569 total time=   1.5s
# [CV 5/5] END criterion=entropy, max_depth=58, max_features=log2, min_samples_leaf=46, min_samples_split=57, min_weight_fraction_leaf=0.34690889474134134, n_estimators=802;, score=0.547 total time=   1.5s
# [CV 1/5] END criterion=entropy, max_depth=87, max_features=sqrt, min_samples_leaf=88, min_samples_split=97, min_weight_fraction_leaf=0.37821856414746313, n_estimators=319;, score=0.556 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=87, max_features=sqrt, min_samples_leaf=88, min_samples_split=97, min_weight_fraction_leaf=0.37821856414746313, n_estimators=319;, score=0.583 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=87, max_features=sqrt, min_samples_leaf=88, min_samples_split=97, min_weight_fraction_leaf=0.37821856414746313, n_estimators=319;, score=0.552 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=87, max_features=sqrt, min_samples_leaf=88, min_samples_split=97, min_weight_fraction_leaf=0.37821856414746313, n_estimators=319;, score=0.542 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=87, max_features=sqrt, min_samples_leaf=88, min_samples_split=97, min_weight_fraction_leaf=0.37821856414746313, n_estimators=319;, score=0.551 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=98, min_weight_fraction_leaf=0.11798152995371386, n_estimators=561;, score=0.590 total time=   1.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=98, min_weight_fraction_leaf=0.11798152995371386, n_estimators=561;, score=0.622 total time=   1.3s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=98, min_weight_fraction_leaf=0.11798152995371386, n_estimators=561;, score=0.573 total time=   1.7s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=98, min_weight_fraction_leaf=0.11798152995371386, n_estimators=561;, score=0.594 total time=   1.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=98, min_weight_fraction_leaf=0.11798152995371386, n_estimators=561;, score=0.575 total time=   1.3s
# [CV 1/5] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=50, min_samples_split=39, min_weight_fraction_leaf=0.04380219853927714, n_estimators=971;, score=0.618 total time=   4.7s
# [CV 2/5] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=50, min_samples_split=39, min_weight_fraction_leaf=0.04380219853927714, n_estimators=971;, score=0.604 total time=   3.9s
# [CV 3/5] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=50, min_samples_split=39, min_weight_fraction_leaf=0.04380219853927714, n_estimators=971;, score=0.611 total time=   3.9s
# [CV 4/5] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=50, min_samples_split=39, min_weight_fraction_leaf=0.04380219853927714, n_estimators=971;, score=0.597 total time=   4.6s
# [CV 5/5] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=50, min_samples_split=39, min_weight_fraction_leaf=0.04380219853927714, n_estimators=971;, score=0.551 total time=   4.0s
# [CV 1/5] END criterion=gini, max_depth=90, max_features=log2, min_samples_leaf=10, min_samples_split=64, min_weight_fraction_leaf=0.4507398578590375, n_estimators=883;, score=0.562 total time=   1.7s
# [CV 2/5] END criterion=gini, max_depth=90, max_features=log2, min_samples_leaf=10, min_samples_split=64, min_weight_fraction_leaf=0.4507398578590375, n_estimators=883;, score=0.583 total time=   1.7s
# [CV 3/5] END criterion=gini, max_depth=90, max_features=log2, min_samples_leaf=10, min_samples_split=64, min_weight_fraction_leaf=0.4507398578590375, n_estimators=883;, score=0.569 total time=   1.6s
# [CV 4/5] END criterion=gini, max_depth=90, max_features=log2, min_samples_leaf=10, min_samples_split=64, min_weight_fraction_leaf=0.4507398578590375, n_estimators=883;, score=0.542 total time=   1.8s
# [CV 5/5] END criterion=gini, max_depth=90, max_features=log2, min_samples_leaf=10, min_samples_split=64, min_weight_fraction_leaf=0.4507398578590375, n_estimators=883;, score=0.537 total time=   2.4s
# [CV 1/5] END criterion=gini, max_depth=30, max_features=None, min_samples_leaf=50, min_samples_split=9, min_weight_fraction_leaf=0.38581131204400315, n_estimators=468;, score=0.552 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=30, max_features=None, min_samples_leaf=50, min_samples_split=9, min_weight_fraction_leaf=0.38581131204400315, n_estimators=468;, score=0.590 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=30, max_features=None, min_samples_leaf=50, min_samples_split=9, min_weight_fraction_leaf=0.38581131204400315, n_estimators=468;, score=0.559 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=30, max_features=None, min_samples_leaf=50, min_samples_split=9, min_weight_fraction_leaf=0.38581131204400315, n_estimators=468;, score=0.556 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=30, max_features=None, min_samples_leaf=50, min_samples_split=9, min_weight_fraction_leaf=0.38581131204400315, n_estimators=468;, score=0.547 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=3, min_samples_split=45, min_weight_fraction_leaf=0.15276391699522207, n_estimators=274;, score=0.552 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=3, min_samples_split=45, min_weight_fraction_leaf=0.15276391699522207, n_estimators=274;, score=0.590 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=3, min_samples_split=45, min_weight_fraction_leaf=0.15276391699522207, n_estimators=274;, score=0.559 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=3, min_samples_split=45, min_weight_fraction_leaf=0.15276391699522207, n_estimators=274;, score=0.580 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=3, min_samples_split=45, min_weight_fraction_leaf=0.15276391699522207, n_estimators=274;, score=0.575 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=46, min_samples_split=82, min_weight_fraction_leaf=0.09804700628038693, n_estimators=350;, score=0.597 total time=   1.7s
# [CV 2/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=46, min_samples_split=82, min_weight_fraction_leaf=0.09804700628038693, n_estimators=350;, score=0.590 total time=   1.6s
# [CV 3/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=46, min_samples_split=82, min_weight_fraction_leaf=0.09804700628038693, n_estimators=350;, score=0.590 total time=   1.2s
# [CV 4/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=46, min_samples_split=82, min_weight_fraction_leaf=0.09804700628038693, n_estimators=350;, score=0.587 total time=   1.2s
# [CV 5/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=46, min_samples_split=82, min_weight_fraction_leaf=0.09804700628038693, n_estimators=350;, score=0.564 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=5, min_samples_split=24, min_weight_fraction_leaf=0.3968843854271592, n_estimators=543;, score=0.552 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=5, min_samples_split=24, min_weight_fraction_leaf=0.3968843854271592, n_estimators=543;, score=0.590 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=5, min_samples_split=24, min_weight_fraction_leaf=0.3968843854271592, n_estimators=543;, score=0.559 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=5, min_samples_split=24, min_weight_fraction_leaf=0.3968843854271592, n_estimators=543;, score=0.556 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=6, max_features=None, min_samples_leaf=5, min_samples_split=24, min_weight_fraction_leaf=0.3968843854271592, n_estimators=543;, score=0.547 total time=   1.3s
# [CV 1/5] END criterion=entropy, max_depth=18, max_features=None, min_samples_leaf=14, min_samples_split=53, min_weight_fraction_leaf=0.11191851730511582, n_estimators=750;, score=0.576 total time=   3.2s
# [CV 2/5] END criterion=entropy, max_depth=18, max_features=None, min_samples_leaf=14, min_samples_split=53, min_weight_fraction_leaf=0.11191851730511582, n_estimators=750;, score=0.597 total time=   2.6s
# [CV 3/5] END criterion=entropy, max_depth=18, max_features=None, min_samples_leaf=14, min_samples_split=53, min_weight_fraction_leaf=0.11191851730511582, n_estimators=750;, score=0.576 total time=   2.6s
# [CV 4/5] END criterion=entropy, max_depth=18, max_features=None, min_samples_leaf=14, min_samples_split=53, min_weight_fraction_leaf=0.11191851730511582, n_estimators=750;, score=0.569 total time=   2.6s
# [CV 5/5] END criterion=entropy, max_depth=18, max_features=None, min_samples_leaf=14, min_samples_split=53, min_weight_fraction_leaf=0.11191851730511582, n_estimators=750;, score=0.575 total time=   3.3s
# [CV 1/5] END criterion=log_loss, max_depth=88, max_features=sqrt, min_samples_leaf=77, min_samples_split=28, min_weight_fraction_leaf=0.166070694868108, n_estimators=453;, score=0.583 total time=   1.0s
# [CV 2/5] END criterion=log_loss, max_depth=88, max_features=sqrt, min_samples_leaf=77, min_samples_split=28, min_weight_fraction_leaf=0.166070694868108, n_estimators=453;, score=0.625 total time=   0.9s
# [CV 3/5] END criterion=log_loss, max_depth=88, max_features=sqrt, min_samples_leaf=77, min_samples_split=28, min_weight_fraction_leaf=0.166070694868108, n_estimators=453;, score=0.569 total time=   1.0s
# [CV 4/5] END criterion=log_loss, max_depth=88, max_features=sqrt, min_samples_leaf=77, min_samples_split=28, min_weight_fraction_leaf=0.166070694868108, n_estimators=453;, score=0.583 total time=   1.0s
# [CV 5/5] END criterion=log_loss, max_depth=88, max_features=sqrt, min_samples_leaf=77, min_samples_split=28, min_weight_fraction_leaf=0.166070694868108, n_estimators=453;, score=0.575 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=33, min_samples_split=21, min_weight_fraction_leaf=0.2368308887234234, n_estimators=715;, score=0.566 total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=33, min_samples_split=21, min_weight_fraction_leaf=0.2368308887234234, n_estimators=715;, score=0.615 total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=33, min_samples_split=21, min_weight_fraction_leaf=0.2368308887234234, n_estimators=715;, score=0.562 total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=33, min_samples_split=21, min_weight_fraction_leaf=0.2368308887234234, n_estimators=715;, score=0.583 total time=   1.5s
# [CV 5/5] END criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=33, min_samples_split=21, min_weight_fraction_leaf=0.2368308887234234, n_estimators=715;, score=0.564 total time=   2.1s
# [CV 1/5] END criterion=log_loss, max_depth=65, max_features=None, min_samples_leaf=78, min_samples_split=64, min_weight_fraction_leaf=0.1726823406227611, n_estimators=649;, score=0.559 total time=   1.9s
# [CV 2/5] END criterion=log_loss, max_depth=65, max_features=None, min_samples_leaf=78, min_samples_split=64, min_weight_fraction_leaf=0.1726823406227611, n_estimators=649;, score=0.587 total time=   1.9s
# [CV 3/5] END criterion=log_loss, max_depth=65, max_features=None, min_samples_leaf=78, min_samples_split=64, min_weight_fraction_leaf=0.1726823406227611, n_estimators=649;, score=0.562 total time=   1.9s
# [CV 4/5] END criterion=log_loss, max_depth=65, max_features=None, min_samples_leaf=78, min_samples_split=64, min_weight_fraction_leaf=0.1726823406227611, n_estimators=649;, score=0.562 total time=   1.9s
# [CV 5/5] END criterion=log_loss, max_depth=65, max_features=None, min_samples_leaf=78, min_samples_split=64, min_weight_fraction_leaf=0.1726823406227611, n_estimators=649;, score=0.557 total time=   1.9s
# [CV 1/5] END criterion=log_loss, max_depth=60, max_features=sqrt, min_samples_leaf=74, min_samples_split=16, min_weight_fraction_leaf=0.26829622791104735, n_estimators=641;, score=0.580 total time=   1.6s
# [CV 2/5] END criterion=log_loss, max_depth=60, max_features=sqrt, min_samples_leaf=74, min_samples_split=16, min_weight_fraction_leaf=0.26829622791104735, n_estimators=641;, score=0.608 total time=   1.8s
# [CV 3/5] END criterion=log_loss, max_depth=60, max_features=sqrt, min_samples_leaf=74, min_samples_split=16, min_weight_fraction_leaf=0.26829622791104735, n_estimators=641;, score=0.562 total time=   1.3s
# [CV 4/5] END criterion=log_loss, max_depth=60, max_features=sqrt, min_samples_leaf=74, min_samples_split=16, min_weight_fraction_leaf=0.26829622791104735, n_estimators=641;, score=0.580 total time=   1.2s
# [CV 5/5] END criterion=log_loss, max_depth=60, max_features=sqrt, min_samples_leaf=74, min_samples_split=16, min_weight_fraction_leaf=0.26829622791104735, n_estimators=641;, score=0.561 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=75, max_features=None, min_samples_leaf=15, min_samples_split=37, min_weight_fraction_leaf=0.4158566283707602, n_estimators=769;, score=0.552 total time=   1.7s
# [CV 2/5] END criterion=gini, max_depth=75, max_features=None, min_samples_leaf=15, min_samples_split=37, min_weight_fraction_leaf=0.4158566283707602, n_estimators=769;, score=0.590 total time=   1.7s
# [CV 3/5] END criterion=gini, max_depth=75, max_features=None, min_samples_leaf=15, min_samples_split=37, min_weight_fraction_leaf=0.4158566283707602, n_estimators=769;, score=0.559 total time=   1.6s
# [CV 4/5] END criterion=gini, max_depth=75, max_features=None, min_samples_leaf=15, min_samples_split=37, min_weight_fraction_leaf=0.4158566283707602, n_estimators=769;, score=0.556 total time=   2.8s
# [CV 5/5] END criterion=gini, max_depth=75, max_features=None, min_samples_leaf=15, min_samples_split=37, min_weight_fraction_leaf=0.4158566283707602, n_estimators=769;, score=0.547 total time=   2.0s
# [CV 1/5] END criterion=log_loss, max_depth=87, max_features=log2, min_samples_leaf=70, min_samples_split=20, min_weight_fraction_leaf=0.32868383544157487, n_estimators=705;, score=0.566 total time=   1.3s
# [CV 2/5] END criterion=log_loss, max_depth=87, max_features=log2, min_samples_leaf=70, min_samples_split=20, min_weight_fraction_leaf=0.32868383544157487, n_estimators=705;, score=0.583 total time=   1.3s
# [CV 3/5] END criterion=log_loss, max_depth=87, max_features=log2, min_samples_leaf=70, min_samples_split=20, min_weight_fraction_leaf=0.32868383544157487, n_estimators=705;, score=0.559 total time=   1.3s
# [CV 4/5] END criterion=log_loss, max_depth=87, max_features=log2, min_samples_leaf=70, min_samples_split=20, min_weight_fraction_leaf=0.32868383544157487, n_estimators=705;, score=0.559 total time=   1.3s
# [CV 5/5] END criterion=log_loss, max_depth=87, max_features=log2, min_samples_leaf=70, min_samples_split=20, min_weight_fraction_leaf=0.32868383544157487, n_estimators=705;, score=0.554 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=91, max_features=sqrt, min_samples_leaf=68, min_samples_split=67, min_weight_fraction_leaf=0.1119828599610388, n_estimators=783;, score=0.580 total time=   1.6s
# [CV 2/5] END criterion=gini, max_depth=91, max_features=sqrt, min_samples_leaf=68, min_samples_split=67, min_weight_fraction_leaf=0.1119828599610388, n_estimators=783;, score=0.618 total time=   2.1s
# [CV 3/5] END criterion=gini, max_depth=91, max_features=sqrt, min_samples_leaf=68, min_samples_split=67, min_weight_fraction_leaf=0.1119828599610388, n_estimators=783;, score=0.594 total time=   2.1s
# [CV 4/5] END criterion=gini, max_depth=91, max_features=sqrt, min_samples_leaf=68, min_samples_split=67, min_weight_fraction_leaf=0.1119828599610388, n_estimators=783;, score=0.597 total time=   1.7s
# [CV 5/5] END criterion=gini, max_depth=91, max_features=sqrt, min_samples_leaf=68, min_samples_split=67, min_weight_fraction_leaf=0.1119828599610388, n_estimators=783;, score=0.564 total time=   1.7s
# [CV 1/5] END criterion=log_loss, max_depth=84, max_features=log2, min_samples_leaf=1, min_samples_split=67, min_weight_fraction_leaf=0.38248015526431256, n_estimators=962;, score=0.562 total time=   1.8s
# [CV 2/5] END criterion=log_loss, max_depth=84, max_features=log2, min_samples_leaf=1, min_samples_split=67, min_weight_fraction_leaf=0.38248015526431256, n_estimators=962;, score=0.576 total time=   1.7s
# [CV 3/5] END criterion=log_loss, max_depth=84, max_features=log2, min_samples_leaf=1, min_samples_split=67, min_weight_fraction_leaf=0.38248015526431256, n_estimators=962;, score=0.556 total time=   1.8s
# [CV 4/5] END criterion=log_loss, max_depth=84, max_features=log2, min_samples_leaf=1, min_samples_split=67, min_weight_fraction_leaf=0.38248015526431256, n_estimators=962;, score=0.542 total time=   2.6s
# [CV 5/5] END criterion=log_loss, max_depth=84, max_features=log2, min_samples_leaf=1, min_samples_split=67, min_weight_fraction_leaf=0.38248015526431256, n_estimators=962;, score=0.540 total time=   1.8s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=64, min_samples_split=84, min_weight_fraction_leaf=0.09573256320652729, n_estimators=755;, score=0.597 total time=   2.7s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=64, min_samples_split=84, min_weight_fraction_leaf=0.09573256320652729, n_estimators=755;, score=0.590 total time=   2.7s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=64, min_samples_split=84, min_weight_fraction_leaf=0.09573256320652729, n_estimators=755;, score=0.601 total time=   2.7s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=64, min_samples_split=84, min_weight_fraction_leaf=0.09573256320652729, n_estimators=755;, score=0.587 total time=   3.5s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=64, min_samples_split=84, min_weight_fraction_leaf=0.09573256320652729, n_estimators=755;, score=0.575 total time=   2.7s
# [CV 1/5] END criterion=gini, max_depth=82, max_features=log2, min_samples_leaf=4, min_samples_split=17, min_weight_fraction_leaf=0.27082733927886343, n_estimators=388;, score=0.573 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=82, max_features=log2, min_samples_leaf=4, min_samples_split=17, min_weight_fraction_leaf=0.27082733927886343, n_estimators=388;, score=0.601 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=82, max_features=log2, min_samples_leaf=4, min_samples_split=17, min_weight_fraction_leaf=0.27082733927886343, n_estimators=388;, score=0.566 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=82, max_features=log2, min_samples_leaf=4, min_samples_split=17, min_weight_fraction_leaf=0.27082733927886343, n_estimators=388;, score=0.594 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=82, max_features=log2, min_samples_leaf=4, min_samples_split=17, min_weight_fraction_leaf=0.27082733927886343, n_estimators=388;, score=0.568 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=19, min_samples_split=94, min_weight_fraction_leaf=0.18562714265996755, n_estimators=744;, score=0.552 total time=   2.2s
# [CV 2/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=19, min_samples_split=94, min_weight_fraction_leaf=0.18562714265996755, n_estimators=744;, score=0.587 total time=   2.9s
# [CV 3/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=19, min_samples_split=94, min_weight_fraction_leaf=0.18562714265996755, n_estimators=744;, score=0.562 total time=   2.2s
# [CV 4/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=19, min_samples_split=94, min_weight_fraction_leaf=0.18562714265996755, n_estimators=744;, score=0.566 total time=   2.1s
# [CV 5/5] END criterion=log_loss, max_depth=39, max_features=None, min_samples_leaf=19, min_samples_split=94, min_weight_fraction_leaf=0.18562714265996755, n_estimators=744;, score=0.557 total time=   2.1s
# [CV 1/5] END criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=65, min_samples_split=57, min_weight_fraction_leaf=0.07910172596587839, n_estimators=454;, score=0.597 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=65, min_samples_split=57, min_weight_fraction_leaf=0.07910172596587839, n_estimators=454;, score=0.625 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=65, min_samples_split=57, min_weight_fraction_leaf=0.07910172596587839, n_estimators=454;, score=0.590 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=65, min_samples_split=57, min_weight_fraction_leaf=0.07910172596587839, n_estimators=454;, score=0.597 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=65, min_samples_split=57, min_weight_fraction_leaf=0.07910172596587839, n_estimators=454;, score=0.578 total time=   1.5s
# [CV 1/5] END criterion=log_loss, max_depth=81, max_features=sqrt, min_samples_leaf=74, min_samples_split=33, min_weight_fraction_leaf=0.14054531898751982, n_estimators=999;, score=0.583 total time=   2.3s
# [CV 2/5] END criterion=log_loss, max_depth=81, max_features=sqrt, min_samples_leaf=74, min_samples_split=33, min_weight_fraction_leaf=0.14054531898751982, n_estimators=999;, score=0.622 total time=   2.1s
# [CV 3/5] END criterion=log_loss, max_depth=81, max_features=sqrt, min_samples_leaf=74, min_samples_split=33, min_weight_fraction_leaf=0.14054531898751982, n_estimators=999;, score=0.576 total time=   2.1s
# [CV 4/5] END criterion=log_loss, max_depth=81, max_features=sqrt, min_samples_leaf=74, min_samples_split=33, min_weight_fraction_leaf=0.14054531898751982, n_estimators=999;, score=0.590 total time=   2.1s
# [CV 5/5] END criterion=log_loss, max_depth=81, max_features=sqrt, min_samples_leaf=74, min_samples_split=33, min_weight_fraction_leaf=0.14054531898751982, n_estimators=999;, score=0.578 total time=   2.2s
# [CV 1/5] END criterion=log_loss, max_depth=9, max_features=sqrt, min_samples_leaf=6, min_samples_split=21, min_weight_fraction_leaf=0.1248257312298639, n_estimators=824;, score=0.587 total time=   2.3s
# ...
# [CV 3/5] END criterion=log_loss, max_depth=80, max_features=sqrt, min_samples_leaf=25, min_samples_split=79, min_weight_fraction_leaf=0.21420032723362564, n_estimators=739;, score=0.545 total time=   1.6s
# [CV 4/5] END criterion=log_loss, max_depth=80, max_features=sqrt, min_samples_leaf=25, min_samples_split=79, min_weight_fraction_leaf=0.21420032723362564, n_estimators=739;, score=0.594 total time=   1.5s
# [CV 5/5] END criterion=log_loss, max_depth=80, max_features=sqrt, min_samples_leaf=25, min_samples_split=79, min_weight_fraction_leaf=0.21420032723362564, n_estimators=739;, score=0.618 total time=   1.5s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=None, min_samples_leaf=91, min_samples_split=27, min_weight_fraction_leaf=0.39095939929088414, n_estimators=154;, score=0.562 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=None, min_samples_leaf=91, min_samples_split=27, min_weight_fraction_leaf=0.39095939929088414, n_estimators=154;, score=0.514 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=None, min_samples_leaf=91, min_samples_split=27, min_weight_fraction_leaf=0.39095939929088414, n_estimators=154;, score=0.524 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=None, min_samples_leaf=91, min_samples_split=27, min_weight_fraction_leaf=0.39095939929088414, n_estimators=154;, score=0.562 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=None, min_samples_leaf=91, min_samples_split=27, min_weight_fraction_leaf=0.39095939929088414, n_estimators=154;, score=0.594 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=78, max_features=sqrt, min_samples_leaf=55, min_samples_split=30, min_weight_fraction_leaf=0.184607635152173, n_estimators=387;, score=0.569 total time=   1.2s
# [CV 2/5] END criterion=log_loss, max_depth=78, max_features=sqrt, min_samples_leaf=55, min_samples_split=30, min_weight_fraction_leaf=0.184607635152173, n_estimators=387;, score=0.531 total time=   1.2s
# [CV 3/5] END criterion=log_loss, max_depth=78, max_features=sqrt, min_samples_leaf=55, min_samples_split=30, min_weight_fraction_leaf=0.184607635152173, n_estimators=387;, score=0.542 total time=   0.8s
# [CV 4/5] END criterion=log_loss, max_depth=78, max_features=sqrt, min_samples_leaf=55, min_samples_split=30, min_weight_fraction_leaf=0.184607635152173, n_estimators=387;, score=0.594 total time=   0.8s
# [CV 5/5] END criterion=log_loss, max_depth=78, max_features=sqrt, min_samples_leaf=55, min_samples_split=30, min_weight_fraction_leaf=0.184607635152173, n_estimators=387;, score=0.608 total time=   0.8s
# [CV 1/5] END criterion=log_loss, max_depth=74, max_features=log2, min_samples_leaf=35, min_samples_split=70, min_weight_fraction_leaf=0.2675277191885642, n_estimators=682;, score=0.576 total time=   1.4s
# [CV 2/5] END criterion=log_loss, max_depth=74, max_features=log2, min_samples_leaf=35, min_samples_split=70, min_weight_fraction_leaf=0.2675277191885642, n_estimators=682;, score=0.531 total time=   1.3s
# [CV 3/5] END criterion=log_loss, max_depth=74, max_features=log2, min_samples_leaf=35, min_samples_split=70, min_weight_fraction_leaf=0.2675277191885642, n_estimators=682;, score=0.531 total time=   1.3s
# [CV 4/5] END criterion=log_loss, max_depth=74, max_features=log2, min_samples_leaf=35, min_samples_split=70, min_weight_fraction_leaf=0.2675277191885642, n_estimators=682;, score=0.601 total time=   1.4s
# [CV 5/5] END criterion=log_loss, max_depth=74, max_features=log2, min_samples_leaf=35, min_samples_split=70, min_weight_fraction_leaf=0.2675277191885642, n_estimators=682;, score=0.601 total time=   1.4s
# [CV 1/5] END criterion=log_loss, max_depth=25, max_features=None, min_samples_leaf=85, min_samples_split=35, min_weight_fraction_leaf=0.29726625469024714, n_estimators=765;, score=0.559 total time=   2.4s
# [CV 2/5] END criterion=log_loss, max_depth=25, max_features=None, min_samples_leaf=85, min_samples_split=35, min_weight_fraction_leaf=0.29726625469024714, n_estimators=765;, score=0.510 total time=   2.2s
# [CV 3/5] END criterion=log_loss, max_depth=25, max_features=None, min_samples_leaf=85, min_samples_split=35, min_weight_fraction_leaf=0.29726625469024714, n_estimators=765;, score=0.521 total time=   1.9s
# [CV 4/5] END criterion=log_loss, max_depth=25, max_features=None, min_samples_leaf=85, min_samples_split=35, min_weight_fraction_leaf=0.29726625469024714, n_estimators=765;, score=0.552 total time=   1.9s
# [CV 5/5] END criterion=log_loss, max_depth=25, max_features=None, min_samples_leaf=85, min_samples_split=35, min_weight_fraction_leaf=0.29726625469024714, n_estimators=765;, score=0.580 total time=   2.0s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=53, min_samples_split=78, min_weight_fraction_leaf=0.08488422234280835, n_estimators=507;, score=0.562 total time=   2.1s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=53, min_samples_split=78, min_weight_fraction_leaf=0.08488422234280835, n_estimators=507;, score=0.538 total time=   2.6s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=53, min_samples_split=78, min_weight_fraction_leaf=0.08488422234280835, n_estimators=507;, score=0.566 total time=   2.2s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=53, min_samples_split=78, min_weight_fraction_leaf=0.08488422234280835, n_estimators=507;, score=0.604 total time=   2.0s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=None, min_samples_leaf=53, min_samples_split=78, min_weight_fraction_leaf=0.08488422234280835, n_estimators=507;, score=0.628 total time=   2.0s
# [CV 1/5] END criterion=entropy, max_depth=13, max_features=None, min_samples_leaf=80, min_samples_split=22, min_weight_fraction_leaf=0.4457544136111021, n_estimators=601;, score=0.569 total time=   1.4s
# [CV 2/5] END criterion=entropy, max_depth=13, max_features=None, min_samples_leaf=80, min_samples_split=22, min_weight_fraction_leaf=0.4457544136111021, n_estimators=601;, score=0.514 total time=   1.4s
# [CV 3/5] END criterion=entropy, max_depth=13, max_features=None, min_samples_leaf=80, min_samples_split=22, min_weight_fraction_leaf=0.4457544136111021, n_estimators=601;, score=0.531 total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=13, max_features=None, min_samples_leaf=80, min_samples_split=22, min_weight_fraction_leaf=0.4457544136111021, n_estimators=601;, score=0.562 total time=   1.9s
# [CV 5/5] END criterion=entropy, max_depth=13, max_features=None, min_samples_leaf=80, min_samples_split=22, min_weight_fraction_leaf=0.4457544136111021, n_estimators=601;, score=0.594 total time=   1.6s
# [CV 1/5] END criterion=log_loss, max_depth=75, max_features=sqrt, min_samples_leaf=15, min_samples_split=39, min_weight_fraction_leaf=0.2699308858082386, n_estimators=165;, score=0.576 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=75, max_features=sqrt, min_samples_leaf=15, min_samples_split=39, min_weight_fraction_leaf=0.2699308858082386, n_estimators=165;, score=0.542 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=75, max_features=sqrt, min_samples_leaf=15, min_samples_split=39, min_weight_fraction_leaf=0.2699308858082386, n_estimators=165;, score=0.535 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=75, max_features=sqrt, min_samples_leaf=15, min_samples_split=39, min_weight_fraction_leaf=0.2699308858082386, n_estimators=165;, score=0.597 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=75, max_features=sqrt, min_samples_leaf=15, min_samples_split=39, min_weight_fraction_leaf=0.2699308858082386, n_estimators=165;, score=0.611 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=log2, min_samples_leaf=38, min_samples_split=7, min_weight_fraction_leaf=0.3336137882543911, n_estimators=319;, score=0.566 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=log2, min_samples_leaf=38, min_samples_split=7, min_weight_fraction_leaf=0.3336137882543911, n_estimators=319;, score=0.542 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=log2, min_samples_leaf=38, min_samples_split=7, min_weight_fraction_leaf=0.3336137882543911, n_estimators=319;, score=0.531 total time=   0.6s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=log2, min_samples_leaf=38, min_samples_split=7, min_weight_fraction_leaf=0.3336137882543911, n_estimators=319;, score=0.583 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=log2, min_samples_leaf=38, min_samples_split=7, min_weight_fraction_leaf=0.3336137882543911, n_estimators=319;, score=0.604 total time=   0.6s
# [CV 1/5] END criterion=log_loss, max_depth=50, max_features=sqrt, min_samples_leaf=92, min_samples_split=31, min_weight_fraction_leaf=0.30795703436881433, n_estimators=659;, score=0.566 total time=   1.3s
# [CV 2/5] END criterion=log_loss, max_depth=50, max_features=sqrt, min_samples_leaf=92, min_samples_split=31, min_weight_fraction_leaf=0.30795703436881433, n_estimators=659;, score=0.524 total time=   1.2s
# [CV 3/5] END criterion=log_loss, max_depth=50, max_features=sqrt, min_samples_leaf=92, min_samples_split=31, min_weight_fraction_leaf=0.30795703436881433, n_estimators=659;, score=0.528 total time=   1.3s
# [CV 4/5] END criterion=log_loss, max_depth=50, max_features=sqrt, min_samples_leaf=92, min_samples_split=31, min_weight_fraction_leaf=0.30795703436881433, n_estimators=659;, score=0.573 total time=   1.6s
# [CV 5/5] END criterion=log_loss, max_depth=50, max_features=sqrt, min_samples_leaf=92, min_samples_split=31, min_weight_fraction_leaf=0.30795703436881433, n_estimators=659;, score=0.611 total time=   1.7s
# [CV 1/5] END criterion=gini, max_depth=57, max_features=log2, min_samples_leaf=13, min_samples_split=76, min_weight_fraction_leaf=0.3075057646737653, n_estimators=937;, score=0.559 total time=   1.8s
# [CV 2/5] END criterion=gini, max_depth=57, max_features=log2, min_samples_leaf=13, min_samples_split=76, min_weight_fraction_leaf=0.3075057646737653, n_estimators=937;, score=0.535 total time=   1.8s
# [CV 3/5] END criterion=gini, max_depth=57, max_features=log2, min_samples_leaf=13, min_samples_split=76, min_weight_fraction_leaf=0.3075057646737653, n_estimators=937;, score=0.528 total time=   1.8s
# [CV 4/5] END criterion=gini, max_depth=57, max_features=log2, min_samples_leaf=13, min_samples_split=76, min_weight_fraction_leaf=0.3075057646737653, n_estimators=937;, score=0.580 total time=   1.8s
# [CV 5/5] END criterion=gini, max_depth=57, max_features=log2, min_samples_leaf=13, min_samples_split=76, min_weight_fraction_leaf=0.3075057646737653, n_estimators=937;, score=0.615 total time=   1.8s
# [CV 1/5] END criterion=gini, max_depth=67, max_features=log2, min_samples_leaf=66, min_samples_split=38, min_weight_fraction_leaf=0.41896191140755085, n_estimators=503;, score=0.559 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=67, max_features=log2, min_samples_leaf=66, min_samples_split=38, min_weight_fraction_leaf=0.41896191140755085, n_estimators=503;, score=0.545 total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=67, max_features=log2, min_samples_leaf=66, min_samples_split=38, min_weight_fraction_leaf=0.41896191140755085, n_estimators=503;, score=0.521 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=67, max_features=log2, min_samples_leaf=66, min_samples_split=38, min_weight_fraction_leaf=0.41896191140755085, n_estimators=503;, score=0.542 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=67, max_features=log2, min_samples_leaf=66, min_samples_split=38, min_weight_fraction_leaf=0.41896191140755085, n_estimators=503;, score=0.611 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=99, max_features=sqrt, min_samples_leaf=79, min_samples_split=47, min_weight_fraction_leaf=0.3742679220780493, n_estimators=241;, score=0.552 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=99, max_features=sqrt, min_samples_leaf=79, min_samples_split=47, min_weight_fraction_leaf=0.3742679220780493, n_estimators=241;, score=0.556 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=99, max_features=sqrt, min_samples_leaf=79, min_samples_split=47, min_weight_fraction_leaf=0.3742679220780493, n_estimators=241;, score=0.521 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=99, max_features=sqrt, min_samples_leaf=79, min_samples_split=47, min_weight_fraction_leaf=0.3742679220780493, n_estimators=241;, score=0.566 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=99, max_features=sqrt, min_samples_leaf=79, min_samples_split=47, min_weight_fraction_leaf=0.3742679220780493, n_estimators=241;, score=0.590 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=29, max_features=sqrt, min_samples_leaf=7, min_samples_split=35, min_weight_fraction_leaf=0.3006499839443084, n_estimators=187;, score=0.569 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=29, max_features=sqrt, min_samples_leaf=7, min_samples_split=35, min_weight_fraction_leaf=0.3006499839443084, n_estimators=187;, score=0.556 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=29, max_features=sqrt, min_samples_leaf=7, min_samples_split=35, min_weight_fraction_leaf=0.3006499839443084, n_estimators=187;, score=0.524 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=29, max_features=sqrt, min_samples_leaf=7, min_samples_split=35, min_weight_fraction_leaf=0.3006499839443084, n_estimators=187;, score=0.580 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=29, max_features=sqrt, min_samples_leaf=7, min_samples_split=35, min_weight_fraction_leaf=0.3006499839443084, n_estimators=187;, score=0.611 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=87, min_samples_split=29, min_weight_fraction_leaf=0.30858853673515824, n_estimators=678;, score=0.556 total time=   1.6s
# [CV 2/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=87, min_samples_split=29, min_weight_fraction_leaf=0.30858853673515824, n_estimators=678;, score=0.510 total time=   1.7s
# [CV 3/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=87, min_samples_split=29, min_weight_fraction_leaf=0.30858853673515824, n_estimators=678;, score=0.528 total time=   2.4s
# [CV 4/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=87, min_samples_split=29, min_weight_fraction_leaf=0.30858853673515824, n_estimators=678;, score=0.556 total time=   1.6s
# [CV 5/5] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=87, min_samples_split=29, min_weight_fraction_leaf=0.30858853673515824, n_estimators=678;, score=0.573 total time=   1.6s
# [CV 1/5] END criterion=log_loss, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=21, min_weight_fraction_leaf=0.03400618389369631, n_estimators=569;, score=0.556 total time=   3.0s
# [CV 2/5] END criterion=log_loss, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=21, min_weight_fraction_leaf=0.03400618389369631, n_estimators=569;, score=0.531 total time=   2.9s
# [CV 3/5] END criterion=log_loss, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=21, min_weight_fraction_leaf=0.03400618389369631, n_estimators=569;, score=0.608 total time=   3.7s
# [CV 4/5] END criterion=log_loss, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=21, min_weight_fraction_leaf=0.03400618389369631, n_estimators=569;, score=0.618 total time=   3.0s
# [CV 5/5] END criterion=log_loss, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=21, min_weight_fraction_leaf=0.03400618389369631, n_estimators=569;, score=0.649 total time=   2.9s

# %%
best_configurations
# Out:
# [{'hyper-parameters': {'criterion': 'gini',
#    'max_depth': 15,
#    'max_features': None,
#    'min_samples_leaf': 21,
#    'min_samples_split': 53,
#    'min_weight_fraction_leaf': 0.007467177973771055,
#    'n_estimators': 990},
#   'performance_estimate': 0.56875},
#  {'hyper-parameters': {'criterion': 'gini',
#    'max_depth': 67,
#    'max_features': 'log2',
#    'min_samples_leaf': 25,
#    'min_samples_split': 32,
#    'min_weight_fraction_leaf': 0.046399350042537646,
#    'n_estimators': 398},
#   'performance_estimate': 0.675},
#  {'hyper-parameters': {'criterion': 'entropy',
#    'max_depth': 31,
#    'max_features': 'sqrt',
#    'min_samples_leaf': 21,
#    'min_samples_split': 19,
#    'min_weight_fraction_leaf': 0.03602627819896431,
#    'n_estimators': 332},
#   'performance_estimate': 0.625},
#  {'hyper-parameters': {'criterion': 'log_loss',
#    'max_depth': 19,
#    'max_features': 'log2',
#    'min_samples_leaf': 5,
#    'min_samples_split': 63,
#    'min_weight_fraction_leaf': 0.013685318608450292,
#    'n_estimators': 380},
#   'performance_estimate': 0.5625},
#  {'hyper-parameters': {'criterion': 'gini',
#    'max_depth': 40,
#    'max_features': 'log2',
#    'min_samples_leaf': 10,
#    'min_samples_split': 71,
#    'min_weight_fraction_leaf': 0.0010710925393937476,
#    'n_estimators': 438},
#   'performance_estimate': 0.59375},
#  {'hyper-parameters': {'criterion': 'gini',
#    'max_depth': 6,
#    'max_features': None,
#    'min_samples_leaf': 34,
#    'min_samples_split': 65,
#    'min_weight_fraction_leaf': 0.06285991396628254,
#    'n_estimators': 848},
#   'performance_estimate': 0.525},
#  {'hyper-parameters': {'criterion': 'gini',
#    'max_depth': 96,
#    'max_features': None,
#    'min_samples_leaf': 17,
#    'min_samples_split': 27,
#    'min_weight_fraction_leaf': 0.024100229675343032,
#    'n_estimators': 711},
#   'performance_estimate': 0.64375},
#  {'hyper-parameters': {'criterion': 'gini',
#    'max_depth': 20,
#    'max_features': None,
#    'min_samples_leaf': 45,
#    'min_samples_split': 32,
#    'min_weight_fraction_leaf': 0.02278368483461024,
#    'n_estimators': 263},
#   'performance_estimate': 0.6125},
#  {'hyper-parameters': {'criterion': 'gini',
#    'max_depth': 44,
#    'max_features': None,
#    'min_samples_leaf': 25,
#    'min_samples_split': 46,
#    'min_weight_fraction_leaf': 0.003931757818766979,
#    'n_estimators': 485},
#   'performance_estimate': 0.56875},
#  {'hyper-parameters': {'criterion': 'entropy',
#    'max_depth': 97,
#    'max_features': 'sqrt',
#    'min_samples_leaf': 13,
#    'min_samples_split': 90,
#    'min_weight_fraction_leaf': 0.057043934027790344,
#    'n_estimators': 763},
#   'performance_estimate': 0.6540880503144654}]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize =(10, 7))

plt.boxplot(best_scores)

plt.title("Model Performance Estimates")

plt.ylabel("Accuracy")

plt.show()

# %%
np.array(best_scores).mean()
# Out:
# 0.6029088050314465
